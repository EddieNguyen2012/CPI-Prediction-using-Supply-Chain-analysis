# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
from datetime import datetime
import seaborn as sns

import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller, acf, pacf, ccf
from statsmodels.tsa.seasonal import STL
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, plot_ccf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from feature_engine.creation import  CyclicalFeatures
from feature_engine.timeseries.forecasting import LagFeatures, WindowFeatures

from xgboost import XGBRegressor
import os
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import kaleido
import plotly.io as pio
import scipy.stats as stats
import tensorflow as tf
from xgboost import DMatrix
import shap

# %%
plot_folder = '/Users/eddie/cs163/src/Plots'
data_folder = '/Users/eddie/cs163/src/Data'
pio.renderers.default = 'png'

def replace_with_underscore(x):
    return x.replace(' ', '_')

# %%
df = pd.read_csv('/Users/eddie/cs163/src/Data/final.csv', index_col=['DATE'], parse_dates=['DATE'], )
df = df.asfreq('MS')
df['month'] = df.index.month
df['year'] = df.index.year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Food and Beverages CPI (target)                  236 non-null    float64
#  7   Civilian workers Total compensation              236 non-null    float64
#  8   Private industry workers Total compensation      236 non-null    float64
#  9   State and government workers Total compensation  236 non-null    float64
#  10  DAIRY PRODUCT TOTALS                             236 non-null    float64
#  11  FIELD CROPS, OTHER                               236 non-null    float64
#  12  FOOD FISH                                        69 non-null     float64
#  13  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  14  HORTICULTURE TOTALS                              69 non-null     float64
#  15  LIVESTOCK TOTALS                                 236 non-null    float64
#  16  POULTRY TOTALS                                   236 non-null    float64
#  17  VEGETABLE TOTALS                                 236 non-null    float64
#  18  Gas Price                                        236 non-null    float64
#  19  Commercial Electricity Price                     236 non-null    float64
#  20  Industrial Electricity Price                     236 non-null    float64
#  21  Transportation Electricity Price                 236 non-null    float64
#  22  month                                            236 non-null    int32
#  23  year                                             236 non-null    int32
# dtypes: float64(22), int32(2)
# memory usage: 44.2 KB

# %%
Y = df.iloc[:, 6]
X = df[[c for c in df.columns if c not in ['Food and Beverages CPI (target)']]]

# %%
np.mean(X.iloc[0,:])
# Out:
# 153.67642857142857

# %% [markdown]
# ### Averaging and getting the mean of each index

# %%
def mean_index(data, name):
    nrow, ncol = data.shape
    avg = []
    for row in range(nrow):
        avg.append(np.mean(data.iloc[row,:]))
    return pd.Series(avg, index=data.index, name=name)

mean_only_X = pd.DataFrame(index=X.index)
# mean_only_X['PPI'] = mean_index(X.iloc[:,:6], 'PPI')
mean_only_X[X.iloc[:,:6].columns] = X.iloc[:,:6]
mean_only_X['CE'] = mean_index(X.iloc[:,6:9], 'CE')
mean_only_X['RPI'] = mean_index(X.iloc[:,9:], 'RPI')
mean_only_X['Electricity Price'] = mean_index(X.iloc[:,18:21], 'Electricity Price')
mean_only_X['Gas Price'] = X['Gas Price']

diff_mean_only_X = pd.DataFrame(index=X.index)
# diff_mean_only_X['PPI'] = mean_index(X.iloc[:,:6], 'PPI').diff()
diff_mean_only_X[X.iloc[:,:6].columns] = X.iloc[:,:6].diff()
diff_mean_only_X['CE'] = mean_index(X.iloc[:,6:9], 'CE').diff()
diff_mean_only_X['RPI'] = mean_index(X.iloc[:,9:], 'RPI').diff()
diff_mean_only_X['Electricity Price'] = mean_index(X.iloc[:,18:21], 'Electricity Price').diff()
diff_mean_only_X['Gas Price'] = X['Gas Price'].diff()
diff_mean_only_X.dropna(inplace=True)

diff_y = Y.diff()
diff_y.dropna(inplace=True)

# %%
diff_mean_only_df = diff_mean_only_X.iloc[:,:]
diff_mean_only_df['CPI'] = diff_y
px.line(diff_mean_only_df, width=1280, height=640)

# %%
mean_only_df_vif = diff_mean_only_df # Adds intercept

# Calculate VIF for each predictor
vif_data = pd.DataFrame()
vif_data['Variable'] = mean_only_df_vif.columns
vif_data['VIF'] = [variance_inflation_factor(mean_only_df_vif.values, i) for i in range(mean_only_df_vif.shape[1])]
vif_data
# Out:
#                                        Variable       VIF
# 0                 Frozen Food Manufacturing PPI  1.232552
# 1   Dried and dehydrated Food Manufacturing PPI  1.387089
# 2          Seafood Production and Packaging PPI  1.215888
# 3                  Snack Food Manufacturing PPI  1.231758
# 4             Perishable Food Manufacturing PPI  1.067939
# 5              Food and Beverages Retailers PPI  1.142272
# 6                                            CE  1.085985
# 7                                           RPI  1.180559
# 8                             Electricity Price  1.109627
# 9                                     Gas Price  1.157441
# 10                                          CPI  1.598414

# %%
for column in diff_mean_only_X.columns:
    print(column , ' :', stats.shapiro(diff_mean_only_X[column]))
# Out:
# Frozen Food Manufacturing PPI  : ShapiroResult(statistic=0.7326894551886755, pvalue=3.4565053647348475e-19)
# Dried and dehydrated Food Manufacturing PPI  : ShapiroResult(statistic=0.8365219918597775, pvalue=5.141468716660006e-15)
# Seafood Production and Packaging PPI  : ShapiroResult(statistic=0.9527796076183269, pvalue=6.012654370205769e-07)
# Snack Food Manufacturing PPI  : ShapiroResult(statistic=0.7057086770584114, pvalue=4.5446400056928515e-20)
# Perishable Food Manufacturing PPI  : ShapiroResult(statistic=0.6458799005682461, pvalue=7.97172335169679e-22)
# Food and Beverages Retailers PPI  : ShapiroResult(statistic=0.9844788172600474, pvalue=0.011468321087542177)
# CE  : ShapiroResult(statistic=0.6670475077549789, pvalue=3.1272582636715557e-21)
# RPI  : ShapiroResult(statistic=0.8443015669176146, pvalue=1.2429423937139682e-14)
# Electricity Price  : ShapiroResult(statistic=0.9788379020072603, pvalue=0.0013787618681688294)
# Gas Price  : ShapiroResult(statistic=0.9551356166014994, pvalue=1.0871824834178518e-06)

# %% [markdown]
# ### KNN Imputation for Fish Food and Horticulture

# %%
imputer = KNNImputer(n_neighbors=7)
# scaler = StandardScaler()
RPI_df = X.iloc[:,9:-2]
# RPI_df = pd.DataFrame(scaler.fit_transform(RPI_df), columns=RPI_df.columns, index=X.index)
RPI_df_imputed = pd.DataFrame(imputer.fit_transform(RPI_df), columns=RPI_df.columns, index=X.index)

for column in ['FOOD FISH', 'HORTICULTURE TOTALS']:
    data = pd.DataFrame({
        'Pre Imputed': RPI_df[column], 
        'Imputed': RPI_df_imputed[column]
    }, index=X.index)
    data_melted = data.melt(var_name='Type', value_name='Value', ignore_index=False)
    fig = px.box(data_melted, title='Pre Imputed vs Imputed ' + column, x = 'Type', y = 'Value')
    fig.write_image(os.path.join(plot_folder,'KNN_Imputed_boxplot_for_' + replace_with_underscore(column) + '.png'), width=1280, height=640)
    fig.show()
    
RPI_df_imputed_melted = RPI_df_imputed.melt(value_name='Value', var_name='Commodity', ignore_index=False)
# RPI_df_imputed_melted = RPI_df_imputed_melted[RPI_df_imputed_melted['Commodity'].isin(['FOOD FISH', 'HORTICULTURE TOTALS'])]
fig = px.line(RPI_df_imputed_melted, x=RPI_df_imputed_melted.index, y='Value', color='Commodity')
fig.write_image(os.path.join(plot_folder,'Imputed_RPI_timeseries.png'), width=1280, height=640)
fig.show()

# %% [markdown]
# After the imputation, the data for FOOD FISH and HORTICULTURE appear to maintain the normal distribution but have new outliers. However, based on the timeseries line plot with other commodities RPI, the outliers are reasonable because other indices also have strong outliers at these periods. So, we can use the imputed data for further analysis.

# %%
# Update newly imputed values
X.update(RPI_df_imputed)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Civilian workers Total compensation              236 non-null    float64
#  7   Private industry workers Total compensation      236 non-null    float64
#  8   State and government workers Total compensation  236 non-null    float64
#  9   DAIRY PRODUCT TOTALS                             236 non-null    float64
#  10  FIELD CROPS, OTHER                               236 non-null    float64
#  11  FOOD FISH                                        236 non-null    float64
#  12  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  13  HORTICULTURE TOTALS                              236 non-null    float64
#  14  LIVESTOCK TOTALS                                 236 non-null    float64
#  15  POULTRY TOTALS                                   236 non-null    float64
#  16  VEGETABLE TOTALS                                 236 non-null    float64
#  17  Gas Price                                        236 non-null    float64
#  18  Commercial Electricity Price                     236 non-null    float64
#  19  Industrial Electricity Price                     236 non-null    float64
#  20  Transportation Electricity Price                 236 non-null    float64
#  21  month                                            236 non-null    int32
#  22  year                                             236 non-null    int32
# dtypes: float64(21), int32(2)
# memory usage: 42.4 KB

# %% [markdown]
# #### Consumer Expenditures Imputation
#
# Since CE data is 2 months behind others, we will also use KNN Imputation to fill the missing value for them. Notes that this is only 2/236 so it should not affect the distribution.

# %%
imputer = KNNImputer(n_neighbors=5)
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns, index=X.index)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Civilian workers Total compensation              236 non-null    float64
#  7   Private industry workers Total compensation      236 non-null    float64
#  8   State and government workers Total compensation  236 non-null    float64
#  9   DAIRY PRODUCT TOTALS                             236 non-null    float64
#  10  FIELD CROPS, OTHER                               236 non-null    float64
#  11  FOOD FISH                                        236 non-null    float64
#  12  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  13  HORTICULTURE TOTALS                              236 non-null    float64
#  14  LIVESTOCK TOTALS                                 236 non-null    float64
#  15  POULTRY TOTALS                                   236 non-null    float64
#  16  VEGETABLE TOTALS                                 236 non-null    float64
#  17  Gas Price                                        236 non-null    float64
#  18  Commercial Electricity Price                     236 non-null    float64
#  19  Industrial Electricity Price                     236 non-null    float64
#  20  Transportation Electricity Price                 236 non-null    float64
#  21  month                                            236 non-null    float64
#  22  year                                             236 non-null    float64
# dtypes: float64(23)
# memory usage: 44.2 KB

# %% [markdown]
# # Timeseries features engineering
#
# ## Feature lags
# ### Define function

# %%
def create_lag_features(df, lags, features= []):
    lag_f = LagFeatures(periods=lags)
    if isinstance(df, pd.Series):
        res_df = lag_f.fit_transform(pd.DataFrame(df)).iloc[:,1:].fillna(method='bfill')
        return res_df
    elif isinstance(df, pd.DataFrame):
        res_df = lag_f.fit_transform(df[features]).iloc[:,len(features):].fillna(method='bfill')
        return res_df

# %% [markdown]
# ### Feature selection using Cross-correlation plot

# %%
features = diff_mean_only_X.columns
nrow = 4
ncol = 3

fig, axs = plt.subplots(nrows=nrow, ncols=ncol, figsize=(13,8))

# Flatten the axs array for easier indexing in a loop
axs = axs.flatten()

for i in range(len(features)):
    plot_ccf(diff_mean_only_X[features[i]], diff_y, title='Change of ' + features[i] + '\nvs change of CPI', ax=axs[i], negative_lags=True, alpha=0.05)

# Hide any unused subplots if there are fewer features than subplots
for j in range(len(features), len(axs)):
    axs[j].set_visible(False)

# plt.suptitle('Cross-correlation plots of the changes of all variables to changes of CPI')
plt.tight_layout()
plt.suptitle('Cross-correlation plots', y=1.05)
plt.savefig(os.path.join(plot_folder, 'CCF_of_diff_features_vs_diff_CPI.png'))
plt.show()

# %%
def find_best_lag_of_columns(data, target):
    result = []
    
    for column in data.columns:
        tmp = []
        # Calculate cross-correlation
        res = ccf(data[column], target, nlags=20)
        
        # Linear search for significant lags (cut-off at 95% confidence level)
        for i in range(1, len(res)):
            if np.abs(res[i]) > 0.05:
                tmp.append(i)
            else:
                 break
        if len(tmp) > 0:
            result.append(tmp)
        
    return result, data.columns[:len(result)]

# %%
res, cols = find_best_lag_of_columns(diff_mean_only_X.iloc[:, :-1], diff_y)
for i in range(len(cols)):
    tmp = create_lag_features(diff_mean_only_df[cols[i]], lags=res[i])
    diff_mean_only_X[tmp.columns] = tmp
diff_mean_only_X
# Out:
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /tmp/ipykernel_87093/1168535662.py:4: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...
# 2005-03-01          -0.043333      0.167  ...
# 2005-04-01           0.133333      0.165  ...
# 2005-05-01           0.066667     -0.080  ...
# 2005-06-01           0.396667     -0.007  ...
# ...                       ...        ...  ...
# 2024-04-01           0.166667      0.191  ...
# 2024-05-01          -0.086667     -0.008  ...
# 2024-06-01           0.546667     -0.149  ...
# 2024-07-01           0.443333      0.024  ...
# 2024-08-01          -0.083333     -0.093  ...
#
#             Food and Beverages Retailers PPI_lag_9  \
# DATE
# 2005-02-01                                   3.100
# 2005-03-01                                   3.100
# 2005-04-01                                   3.100
# 2005-05-01                                   3.100
# 2005-06-01                                   3.100
# ...                                            ...
# 2024-04-01                                  -3.763
# 2024-05-01                                   5.040
# 2024-06-01                                   0.996
# 2024-07-01                                   0.948
# 2024-08-01                                  -0.744
#
#             Food and Beverages Retailers PPI_lag_10  \
# DATE
# 2005-02-01                                    3.100
# 2005-03-01                                    3.100
# 2005-04-01                                    3.100
# 2005-05-01                                    3.100
# 2005-06-01                                    3.100
# ...                                             ...
# 2024-04-01                                    3.305
# 2024-05-01                                   -3.763
# 2024-06-01                                    5.040
# 2024-07-01                                    0.996
# 2024-08-01                                    0.948
#
#             Food and Beverages Retailers PPI_lag_11  \
# DATE
# 2005-02-01                                    3.100
# 2005-03-01                                    3.100
# 2005-04-01                                    3.100
# 2005-05-01                                    3.100
# 2005-06-01                                    3.100
# ...                                             ...
# 2024-04-01                                   -0.427
# 2024-05-01                                    3.305
# 2024-06-01                                   -3.763
# 2024-07-01                                    5.040
# 2024-08-01                                    0.996
#
#             Food and Beverages Retailers PPI_lag_12  CE_lag_1  CE_lag_2  \
# DATE
# 2005-02-01                                    3.100  0.000000  0.000000
# 2005-03-01                                    3.100  0.000000  0.000000
# 2005-04-01                                    3.100  0.000000  0.000000
# 2005-05-01                                    3.100 -0.300000  0.000000
# 2005-06-01                                    3.100  0.000000 -0.300000
# ...                                             ...       ...       ...
# 2024-04-01                                    0.326  0.000000  0.000000
# 2024-05-01                                   -0.427 -0.066667  0.000000
# 2024-06-01                                    3.305  0.000000 -0.066667
# 2024-07-01                                   -3.763  0.000000  0.000000
# 2024-08-01                                    5.040 -0.233333  0.000000
#
#             RPI_lag_1  RPI_lag_2  Electricity Price_lag_1  \
# DATE
# 2005-02-01   1.361500   1.361500                 0.153333
# 2005-03-01   1.361500   1.361500                 0.153333
# 2005-04-01   2.353083   1.361500                -0.043333
# 2005-05-01   0.672083   2.353083                 0.133333
# 2005-06-01  -1.931667   0.672083                 0.066667
# ...               ...        ...                      ...
# 2024-04-01  -0.241143   3.565786                -0.430000
# 2024-05-01  -1.572071  -0.241143                 0.166667
# 2024-06-01  -0.383429  -1.572071                -0.086667
# 2024-07-01   5.842214  -0.383429                 0.546667
# 2024-08-01  -1.467571   5.842214                 0.443333
#
#             Electricity Price_lag_2
# DATE
# 2005-02-01                 0.153333
# 2005-03-01                 0.153333
# 2005-04-01                 0.153333
# 2005-05-01                -0.043333
# 2005-06-01                 0.133333
# ...                             ...
# 2024-04-01                 0.096667
# 2024-05-01                -0.430000
# 2024-06-01                 0.166667
# 2024-07-01                -0.086667
# 2024-08-01                 0.546667
#
# [235 rows x 76 columns]

# %% [markdown]
# The plots shows that the changes of PPI indices (except Perishable Food), and CE indices from previous lags has significant impacts on CPI. So, we will create lags features accordingly

# %% [markdown]
# ## Cyclical features

# %%
def cyclical_features(df, features):
    cycler = CyclicalFeatures()
    return cycler.fit_transform(df[features]).iloc[:,2:]

# %%
time_features = ['month', 'year']
diff_mean_only_X['month'] = diff_mean_only_X.index.month
diff_mean_only_X['year'] = diff_mean_only_X.index.year
cyc_data = cyclical_features(diff_mean_only_X, time_features)
diff_mean_only_X[cyc_data.columns] = cyc_data
# diff_mean_only_X.drop(columns=['year'], inplace=True)

# %%
diff_mean_only_X
# Out:
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  RPI_lag_1  RPI_lag_2  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...   1.361500   1.361500
# 2005-03-01          -0.043333      0.167  ...   1.361500   1.361500
# 2005-04-01           0.133333      0.165  ...   2.353083   1.361500
# 2005-05-01           0.066667     -0.080  ...   0.672083   2.353083
# 2005-06-01           0.396667     -0.007  ...  -1.931667   0.672083
# ...                       ...        ...  ...        ...        ...
# 2024-04-01           0.166667      0.191  ...  -0.241143   3.565786
# 2024-05-01          -0.086667     -0.008  ...  -1.572071  -0.241143
# 2024-06-01           0.546667     -0.149  ...  -0.383429  -1.572071
# 2024-07-01           0.443333      0.024  ...   5.842214  -0.383429
# 2024-08-01          -0.083333     -0.093  ...  -1.467571   5.842214
#
#             Electricity Price_lag_1  Electricity Price_lag_2  month  year  \
# DATE
# 2005-02-01                 0.153333                 0.153333      2  2005
# 2005-03-01                 0.153333                 0.153333      3  2005
# 2005-04-01                -0.043333                 0.153333      4  2005
# 2005-05-01                 0.133333                -0.043333      5  2005
# 2005-06-01                 0.066667                 0.133333      6  2005
# ...                             ...                      ...    ...   ...
# 2024-04-01                -0.430000                 0.096667      4  2024
# 2024-05-01                 0.166667                -0.430000      5  2024
# 2024-06-01                -0.086667                 0.166667      6  2024
# 2024-07-01                 0.546667                -0.086667      7  2024
# 2024-08-01                 0.443333                 0.546667      8  2024
#
#                month_sin     month_cos      year_sin  year_cos
# DATE
# 2005-02-01  8.660254e-01  5.000000e-01 -5.894828e-02  0.998261
# 2005-03-01  1.000000e+00  6.123234e-17 -5.894828e-02  0.998261
# 2005-04-01  8.660254e-01 -5.000000e-01 -5.894828e-02  0.998261
# 2005-05-01  5.000000e-01 -8.660254e-01 -5.894828e-02  0.998261
# 2005-06-01  1.224647e-16 -1.000000e+00 -5.894828e-02  0.998261
# ...                  ...           ...           ...       ...
# 2024-04-01  8.660254e-01 -5.000000e-01 -2.449294e-16  1.000000
# 2024-05-01  5.000000e-01 -8.660254e-01 -2.449294e-16  1.000000
# 2024-06-01  1.224647e-16 -1.000000e+00 -2.449294e-16  1.000000
# 2024-07-01 -5.000000e-01 -8.660254e-01 -2.449294e-16  1.000000
# 2024-08-01 -8.660254e-01 -5.000000e-01 -2.449294e-16  1.000000
#
# [235 rows x 82 columns]

# %% [markdown]
# ## Data Windowing

# %%
windower = WindowFeatures(window=3, functions=['mean', 'std'])
windowed_Y = windower.fit_transform(pd.DataFrame(diff_y, 
                                                 columns=[diff_y.name], 
                                                 index=diff_y.index))
windowed_Y = windowed_Y.fillna(method='bfill').iloc[:,-2:]
diff_mean_only_X[windowed_Y.columns] = windowed_Y
diff_mean_only_X[windowed_Y.columns] = windowed_Y
# Out:
# /tmp/ipykernel_87093/3618009606.py:5: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
diff_mean_only_X.head(5)
# Out:
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                           -0.1
# 2005-03-01                            0.0
# 2005-04-01                            0.1
# 2005-05-01                            0.3
# 2005-06-01                           -0.1
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                         -0.2
# 2005-03-01                                         -0.4
# 2005-04-01                                          0.1
# 2005-05-01                                          0.4
# 2005-06-01                                         -0.5
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                  -1.4
# 2005-03-01                                   0.6
# 2005-04-01                                  -0.1
# 2005-05-01                                   0.3
# 2005-06-01                                   0.6
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                           0.9                                0.4
# 2005-03-01                           0.3                                0.1
# 2005-04-01                           1.1                                0.5
# 2005-05-01                           0.4                                0.8
# 2005-06-01                           0.5                               -0.8
#
#             Food and Beverages Retailers PPI   CE       RPI  \
# DATE
# 2005-02-01                               3.1  0.0  1.361500
# 2005-03-01                              -0.4  0.0  2.353083
# 2005-04-01                              -1.8 -0.3  0.672083
# 2005-05-01                               0.3  0.0 -1.931667
# 2005-06-01                               3.4  0.0  0.681917
#
#             Electricity Price  Gas Price  ...  Electricity Price_lag_1  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...                 0.153333
# 2005-03-01          -0.043333      0.167  ...                 0.153333
# 2005-04-01           0.133333      0.165  ...                -0.043333
# 2005-05-01           0.066667     -0.080  ...                 0.133333
# 2005-06-01           0.396667     -0.007  ...                 0.066667
#
#             Electricity Price_lag_2  month  year     month_sin     month_cos  \
# DATE
# 2005-02-01                 0.153333      2  2005  8.660254e-01  5.000000e-01
# 2005-03-01                 0.153333      3  2005  1.000000e+00  6.123234e-17
# 2005-04-01                 0.153333      4  2005  8.660254e-01 -5.000000e-01
# 2005-05-01                -0.043333      5  2005  5.000000e-01 -8.660254e-01
# 2005-06-01                 0.133333      6  2005  1.224647e-16 -1.000000e+00
#
#             year_sin  year_cos  Food and Beverages CPI (target)_window_3_mean  \
# DATE
# 2005-02-01 -0.058948  0.998261                                       0.566667
# 2005-03-01 -0.058948  0.998261                                       0.566667
# 2005-04-01 -0.058948  0.998261                                       0.566667
# 2005-05-01 -0.058948  0.998261                                       0.566667
# 2005-06-01 -0.058948  0.998261                                       0.600000
#
#             Food and Beverages CPI (target)_window_3_std
# DATE
# 2005-02-01                                      0.568624
# 2005-03-01                                      0.568624
# 2005-04-01                                      0.568624
# 2005-05-01                                      0.568624
# 2005-06-01                                      0.529150
#
# [5 rows x 84 columns]

# %% [markdown]
# ## Effect to CPI by RPI Commodity/ CE Worker segment/ PPI Industry using ARIMA with eXogenous variables (ARIMAX)

# %%
RPI_df = X.iloc[:, 9:].copy()
CE_df = X.iloc[:, 6:9].copy()
PPI_df = X.iloc[:, :6].copy()
category = [RPI_df, CE_df, PPI_df]

# %% [markdown]
# ### Assumption check
#
# #### Stationary of CPI
#
# As we saw in the EDA time series plot of CPI, it is not stationary. So, we will use differencing and use Augmented Dick-Fuller test to determine the level of differencing needed for ARIMAX. Let the threshold be 0.05, our null hypothesis is the time-series has a unit root, which is non-stationary.

# %%
def differencing(X, d):
    X_new = X.values
    for i in range(d):
        X_tmp = np.array(np.zeros(len(X)))
        for index in range(1, len(X)):
            X_tmp[index] = X_new[index] - X_new[index - 1]
        X_new = X_tmp
    
    return pd.Series(X_new, index=X.index)

# %%
adf_test = adfuller(Y)
print(f'ADF Statistic: {adf_test[0]}, p-value: {adf_test[1]}')
# Out:
# ADF Statistic: 0.45283048046851143, p-value: 0.9833666646610939

# %% [markdown]
# Originally, p-value is 0.99 > 0.05. So, we cannot reject the null hypothesis yet and transformation is needed. We will try differencing 1 time.

# %%
for d in range(4):
    adf_test = adfuller(differencing(Y, d))
    print(f'Differencing level {d}: ADF Statistic: {adf_test[0]}, p-value: {adf_test[1]}')
# Out:
# Differencing level 0: ADF Statistic: 0.45283048046851143, p-value: 0.9833666646610939
# Differencing level 1: ADF Statistic: -3.113736842824391, p-value: 0.025553161970907037
# Differencing level 2: ADF Statistic: -12.569769212010181, p-value: 2.0161460645037344e-23
# Differencing level 3: ADF Statistic: -7.6590144763304435, p-value: 1.7083369734366576e-11

# %% [markdown]
# So with 1 time differencing, CPI time-series is already stationary, so we will go with ``d = 1``

# %% [markdown]
# ## Seasonality check

# %%
diff_y = Y.diff().dropna()

# %%
df_diff_seasonal_diff = np.diff(diff_y, n=12)     
 
ad_fuller_result = adfuller(df_diff_seasonal_diff)
 
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -17.355905793334415
# p-value: 5.238063205779815e-30

# %% [markdown]
# The 2 values that are 12 months apart are seasonal using seasonal differencing of degree 1

# %%
plt.plot(diff_y[:36])

# %%
decomposition = STL(differencing(Y, 2))
result = decomposition.fit()
seasonal, trend, resid = result.seasonal, result.trend, result.resid
plt.figure(figsize=(8,6))

plt.subplot(4,1,1)
plt.plot(diff_y)
plt.title('Original Series', fontsize=16)

plt.subplot(4,1,2)
plt.plot(trend)
plt.title('Trend', fontsize=16)

plt.subplot(4,1,3)
plt.plot(seasonal)
plt.title('Seasonal', fontsize=16)

plt.subplot(4,1,4)
plt.plot(resid)
plt.title('Residual', fontsize=16)

plt.tight_layout()
plt.savefig(os.path.join(plot_folder, 'Seasonality_decomposition.png'))

# %%
prediction = seasonal + trend
plt.figure(figsize=(10, 6))
plt.plot(differencing(Y, 2))
plt.plot(prediction)
plt.savefig(os.path.join(plot_folder, 'SLT_prediction.png'))

# %%
resid_mu = resid.mean()
resid_dev = resid.std()

lower = resid_mu - 3*resid_dev
upper = resid_mu + 3*resid_dev

plt.figure(figsize=(10,4))
plt.plot(resid)

plt.fill_between([datetime(2005,1,1), datetime(2024,9,1)], lower, upper, color='g', alpha=0.25, linestyle='--', linewidth=2)
plt.xlim(datetime(2005,1,1), datetime(2024,9,1))

plt.savefig(os.path.join(plot_folder, 'Anamolies_detection.png'))

# %%
anomalies = diff_y[(resid < lower) | (resid > upper)]

plt.figure(figsize=(10,4))
plt.plot(diff_y)
for year in range(2005,2024):
    plt.axvline(datetime(year,1,1), color='k', linestyle='--', alpha=0.5)
    
plt.scatter(anomalies.index, anomalies.values, color='r', marker='D')
plt.savefig(os.path.join(plot_folder, 'Anamolies_points.png'))

# %% [markdown]
# ### AR order and MA order
#
# We will perform ACF and PACF to determine the Autoregressive term and Moving Average term.

# %%
acf = plot_acf(diff_y, lags=40)
acf.savefig(os.path.join(plot_folder, 'ACF.png'))
acf.show()
pacf = plot_pacf(diff_y, lags=40)
pacf.savefig(os.path.join(plot_folder, 'PACF.png'))
pacf.show()
# Out:
# /tmp/ipykernel_87093/4003770003.py:3: UserWarning:
#
# FigureCanvasAgg is non-interactive, and thus cannot be shown
#
# /tmp/ipykernel_87093/4003770003.py:6: UserWarning:
#
# FigureCanvasAgg is non-interactive, and thus cannot be shown

# %% [markdown]
# So MA term should be 9 and AR term should be 5

# %%
from scipy.stats import probplot


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
probplot(differencing(Y, 1), plot=ax, dist='norm')
plt.savefig(os.path.join(plot_folder, 'QQ_plot_of_CPI.png'))
# scaler = StandardScaler()


# standard_Y

# %%
stat, pvalues = stats.shapiro(differencing(Y, 2))
pvalues
# Out:
# 3.679224607707663e-08

# %%
SARIMAX_X_train = diff_mean_only_X.iloc[:-12,:]
SARIMAX_y_train = Y[1:-12]
SARIMAX_X_test = diff_mean_only_X.iloc[-12:,:]
SARIMAX_y_test = Y[-12:]

model = SARIMAX(
    endog=SARIMAX_y_train, 
    exog=SARIMAX_X_train, 
    order=(4, 1, 0), #p,d,q order
    seasonal_order=(0, 1, 1, 9),
)
results = model.fit()

print(results.summary())
results.plot_diagnostics(figsize=(10,10))
plt.savefig(os.path.join(plot_folder, 'SARIMAX_diagnosis.png'))
plt.show()


data_prediction = results.predict(exog=SARIMAX_X_train.iloc[12:], start='01-01-2006')
y_predicted = results.predict(exog= SARIMAX_X_test, start='09-01-2023', end='08-01-2024')

print('Model AIC: ', results.aic)
print('Model BIC: ', results.bic)
print('Balance: ', np.abs(results.aic - results.bic))

print('MSE on dataset: ', mean_squared_error(data_prediction, SARIMAX_y_train[11:]))
print('MAE on dataset: ', mean_squared_error(data_prediction, SARIMAX_y_train[11:]))

print('MSE on test set: ', mean_squared_error(y_predicted, SARIMAX_y_test))
print('MAE on test set: ', mean_squared_error(y_predicted, SARIMAX_y_test))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           90     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.60520D-01    |proj g|=  4.85626D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.38935D-01    |proj g|=  9.20875D-01
#
# At iterate   10    f=  4.24410D-01    |proj g|=  2.93220D-01
#
# At iterate   15    f=  4.11884D-01    |proj g|=  2.60253D-01
#
# At iterate   20    f=  3.91358D-01    |proj g|=  2.11251D-01
#
# At iterate   25    f=  3.66354D-01    |proj g|=  1.71099D-01
#
# At iterate   30    f=  3.49343D-01    |proj g|=  2.51501D-01
#
# At iterate   35    f=  3.40545D-01    |proj g|=  2.34198D-01
#
# At iterate   40    f=  3.28343D-01    |proj g|=  1.03774D-01
#
# At iterate   45    f=  3.21958D-01    |proj g|=  1.30995D-01
# /Users/eddie/miniconda3/envs/cs163/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# At iterate   50    f=  3.17629D-01    |proj g|=  1.76048D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    90     50     53      1     0     0   1.760D-01   3.176D-01
#   F =  0.31762927649446376
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:     Food and Beverages CPI (target)   No. Observations:                  223
# Model:             SARIMAX(4, 1, 0)x(0, 1, [1], 9)   Log Likelihood                 -70.831
# Date:                             Sun, 10 Nov 2024   AIC                            321.663
# Time:                                     18:47:10   BIC                            624.179
# Sample:                                 02-01-2005   HQIC                           443.920
#                                       - 08-01-2023
# Covariance Type:                               opg
# ======================================================================================================================
#                                                          coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Frozen Food Manufacturing PPI                         -0.0110      0.036     -0.309      0.757      -0.081       0.059
# Dried and dehydrated Food Manufacturing PPI            0.0355      0.028      1.275      0.202      -0.019       0.090
# Seafood Production and Packaging PPI                  -0.0096      0.031     -0.306      0.760      -0.071       0.052
# Snack Food Manufacturing PPI                           0.0510      0.047      1.078      0.281      -0.042       0.144
# Perishable Food Manufacturing PPI                      0.0150      0.010      1.533      0.125      -0.004       0.034
# Food and Beverages Retailers PPI                       0.0178      0.018      0.975      0.329      -0.018       0.054
# CE                                                    -0.3181      0.345     -0.921      0.357      -0.995       0.359
# RPI                                                   -0.0196      0.018     -1.089      0.276      -0.055       0.016
# Electricity Price                                     -0.1021      0.159     -0.642      0.521      -0.414       0.210
# Gas Price                                             -0.2928      0.219     -1.338      0.181      -0.722       0.136
# Frozen Food Manufacturing PPI_lag_1                    0.1086      0.079      1.367      0.172      -0.047       0.264
# Frozen Food Manufacturing PPI_lag_2                    0.1027      0.106      0.973      0.330      -0.104       0.310
# Frozen Food Manufacturing PPI_lag_3                    0.1349      0.115      1.174      0.240      -0.090       0.360
# Frozen Food Manufacturing PPI_lag_4                    0.0893      0.127      0.702      0.483      -0.160       0.339
# Frozen Food Manufacturing PPI_lag_5                    0.1347      0.133      1.010      0.313      -0.127       0.396
# Frozen Food Manufacturing PPI_lag_6                    0.1449      0.133      1.093      0.274      -0.115       0.405
# Frozen Food Manufacturing PPI_lag_7                    0.1169      0.125      0.935      0.350      -0.128       0.362
# Frozen Food Manufacturing PPI_lag_8                   -0.0096      0.118     -0.082      0.935      -0.241       0.222
# Frozen Food Manufacturing PPI_lag_9                   -0.0484      0.098     -0.492      0.623      -0.241       0.145
# Frozen Food Manufacturing PPI_lag_10                  -0.0452      0.085     -0.531      0.596      -0.212       0.122
# Frozen Food Manufacturing PPI_lag_11                  -0.0314      0.066     -0.477      0.633      -0.160       0.097
# Frozen Food Manufacturing PPI_lag_12                  -0.0373      0.037     -1.002      0.316      -0.110       0.036
# Dried and dehydrated Food Manufacturing PPI_lag_1      0.0654      0.040      1.618      0.106      -0.014       0.145
# Dried and dehydrated Food Manufacturing PPI_lag_2      0.0567      0.056      1.008      0.313      -0.054       0.167
# Dried and dehydrated Food Manufacturing PPI_lag_3      0.0789      0.061      1.288      0.198      -0.041       0.199
# Dried and dehydrated Food Manufacturing PPI_lag_4      0.0884      0.065      1.354      0.176      -0.040       0.216
# Dried and dehydrated Food Manufacturing PPI_lag_5      0.1133      0.066      1.707      0.088      -0.017       0.243
# Dried and dehydrated Food Manufacturing PPI_lag_6      0.1489      0.067      2.225      0.026       0.018       0.280
# Dried and dehydrated Food Manufacturing PPI_lag_7      0.1537      0.067      2.297      0.022       0.023       0.285
# Dried and dehydrated Food Manufacturing PPI_lag_8      0.1759      0.063      2.793      0.005       0.052       0.299
# Dried and dehydrated Food Manufacturing PPI_lag_9      0.1339      0.058      2.300      0.021       0.020       0.248
# Dried and dehydrated Food Manufacturing PPI_lag_10     0.0938      0.054      1.734      0.083      -0.012       0.200
# Dried and dehydrated Food Manufacturing PPI_lag_11     0.0537      0.043      1.244      0.214      -0.031       0.138
# Dried and dehydrated Food Manufacturing PPI_lag_12     0.0499      0.028      1.763      0.078      -0.006       0.105
# Seafood Production and Packaging PPI_lag_1            -0.0691      0.044     -1.568      0.117      -0.155       0.017
# Seafood Production and Packaging PPI_lag_2            -0.0784      0.045     -1.727      0.084      -0.167       0.011
# Seafood Production and Packaging PPI_lag_3            -0.0626      0.039     -1.616      0.106      -0.138       0.013
# Seafood Production and Packaging PPI_lag_4            -0.0102      0.034     -0.298      0.766      -0.077       0.057
# Snack Food Manufacturing PPI_lag_1                     0.0289      0.061      0.472      0.637      -0.091       0.149
# Snack Food Manufacturing PPI_lag_2                     0.0828      0.080      1.041      0.298      -0.073       0.239
# Snack Food Manufacturing PPI_lag_3                     0.1533      0.087      1.769      0.077      -0.017       0.323
# Snack Food Manufacturing PPI_lag_4                     0.1515      0.109      1.391      0.164      -0.062       0.365
# Snack Food Manufacturing PPI_lag_5                     0.1878      0.121      1.553      0.120      -0.049       0.425
# Snack Food Manufacturing PPI_lag_6                     0.1576      0.132      1.194      0.232      -0.101       0.416
# Snack Food Manufacturing PPI_lag_7                     0.1718      0.138      1.244      0.213      -0.099       0.442
# Snack Food Manufacturing PPI_lag_8                     0.2893      0.136      2.122      0.034       0.022       0.557
# Snack Food Manufacturing PPI_lag_9                     0.2514      0.140      1.793      0.073      -0.023       0.526
# Snack Food Manufacturing PPI_lag_10                    0.1979      0.153      1.290      0.197      -0.103       0.499
# Snack Food Manufacturing PPI_lag_11                    0.1916      0.137      1.394      0.163      -0.078       0.461
# Snack Food Manufacturing PPI_lag_12                    0.1237      0.132      0.937      0.349      -0.135       0.382
# Snack Food Manufacturing PPI_lag_13                    0.1670      0.126      1.330      0.184      -0.079       0.413
# Snack Food Manufacturing PPI_lag_14                    0.1198      0.117      1.026      0.305      -0.109       0.349
# Snack Food Manufacturing PPI_lag_15                    0.1162      0.102      1.143      0.253      -0.083       0.315
# Snack Food Manufacturing PPI_lag_16                    0.0489      0.094      0.518      0.604      -0.136       0.234
# Snack Food Manufacturing PPI_lag_17                    0.0430      0.074      0.579      0.563      -0.103       0.189
# Snack Food Manufacturing PPI_lag_18                    0.0523      0.064      0.814      0.416      -0.074       0.178
# Snack Food Manufacturing PPI_lag_19                    0.0292      0.055      0.533      0.594      -0.078       0.136
# Perishable Food Manufacturing PPI_lag_1                0.0014      0.010      0.145      0.885      -0.018       0.021
# Food and Beverages Retailers PPI_lag_1                 0.0397      0.029      1.364      0.173      -0.017       0.097
# Food and Beverages Retailers PPI_lag_2                 0.0686      0.040      1.695      0.090      -0.011       0.148
# Food and Beverages Retailers PPI_lag_3                 0.0975      0.051      1.930      0.054      -0.001       0.197
# Food and Beverages Retailers PPI_lag_4                 0.0908      0.059      1.535      0.125      -0.025       0.207
# Food and Beverages Retailers PPI_lag_5                 0.1063      0.064      1.651      0.099      -0.020       0.232
# Food and Beverages Retailers PPI_lag_6                 0.1050      0.068      1.549      0.121      -0.028       0.238
# Food and Beverages Retailers PPI_lag_7                 0.1020      0.068      1.504      0.132      -0.031       0.235
# Food and Beverages Retailers PPI_lag_8                 0.0872      0.064      1.356      0.175      -0.039       0.213
# Food and Beverages Retailers PPI_lag_9                 0.0566      0.056      1.014      0.311      -0.053       0.166
# Food and Beverages Retailers PPI_lag_10                0.0204      0.045      0.458      0.647      -0.067       0.108
# Food and Beverages Retailers PPI_lag_11                0.0162      0.031      0.529      0.597      -0.044       0.076
# Food and Beverages Retailers PPI_lag_12                0.0073      0.018      0.409      0.683      -0.028       0.042
# CE_lag_1                                              -0.3769      0.420     -0.898      0.369      -1.199       0.445
# CE_lag_2                                              -0.7850      0.338     -2.323      0.020      -1.447      -0.123
# RPI_lag_1                                              0.0167      0.025      0.676      0.499      -0.032       0.065
# RPI_lag_2                                              0.0060      0.021      0.284      0.776      -0.035       0.047
# Electricity Price_lag_1                               -0.1030      0.178     -0.577      0.564      -0.453       0.247
# Electricity Price_lag_2                               -0.2285      0.150     -1.522      0.128      -0.523       0.066
# month                                                 90.3727    147.486      0.613      0.540    -198.694     379.439
# year                                                  -7.5304   1769.797     -0.004      0.997   -3476.269    3461.208
# month_sin                                              0.0277      0.139      0.200      0.841      -0.244       0.300
# month_cos                                             -0.0461      0.136     -0.339      0.735      -0.313       0.221
# year_sin                                            3.517e+05     78.100   4503.775      0.000    3.52e+05    3.52e+05
# year_cos                                            1.196e+04   2466.918      4.849      0.000    7128.013    1.68e+04
# Food and Beverages CPI (target)_window_3_mean          0.6666      0.348      1.914      0.056      -0.016       1.349
# Food and Beverages CPI (target)_window_3_std           0.4039      0.248      1.632      0.103      -0.081       0.889
# ar.L1                                                  0.2743      0.137      2.002      0.045       0.006       0.543
# ar.L2                                                  0.2855      0.142      2.004      0.045       0.006       0.565
# ar.L3                                                 -0.1486      0.134     -1.110      0.267      -0.411       0.114
# ar.L4                                                  0.3581      0.163      2.191      0.028       0.038       0.678
# ma.S.L9                                               -0.7421      0.130     -5.709      0.000      -0.997      -0.487
# sigma2                                                 0.1090      0.016      6.808      0.000       0.078       0.140
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.88   Jarque-Bera (JB):                 9.37
# Prob(Q):                              0.17   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.22   Skew:                             0.25
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.19e+20. Standard errors may be unstable.
# Model AIC:  321.66265731653084
# Model BIC:  624.1789522303791
# Balance:  302.51629491384824
# MSE on dataset:  0.11594214825335501
# MAE on dataset:  0.11594214825335501
# MSE on test set:  0.514485973627613
# MAE on test set:  0.514485973627613

# %%
y_predicted = results.predict(exog= SARIMAX_X_test, start='02-01-2024', end='08-01-2024')
plt.figure(figsize=(10,10))
plt.plot(SARIMAX_y_test[-7:])
plt.plot(y_predicted)
plt.scatter(y=SARIMAX_y_test[-7:], x=SARIMAX_y_test[-7:].index, marker='*')
plt.scatter(y=y_predicted, x=SARIMAX_y_test[-7:].index, marker='x')
plt.title('Predicted data vs real CPI from SARIMAX for the most recent 5 months')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(    
    os.path.join(plot_folder, 'SARIMAX_prediction.png')
)

# %%
import scipy.stats as stats

stat, pvalues = stats.shapiro(results.resid)
print('Shapiro-Wilks test p-value: ', pvalues)
# Out:
# Shapiro-Wilks test p-value:  1.63954482948696e-31

# %%
data_prediction = results.predict(exog=SARIMAX_X_train.iloc[12:], start='01-01-2006')
plt.figure(figsize=(10,10))
plt.plot(SARIMAX_y_train.iloc[12:])
plt.plot(data_prediction)
plt.title('Predicted data vs real CPI from SARIMAX from 2006 to present')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(
    os.path.join(plot_folder, 'SARIMAX_prediction_whole_data.png')
)

# %% [markdown]
# #### ARIMAX Results

# %% [markdown]
# ### XGBoost

# %%
diff_mean_only_X
# Out:
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  Electricity Price_lag_1  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...                 0.153333
# 2005-03-01          -0.043333      0.167  ...                 0.153333
# 2005-04-01           0.133333      0.165  ...                -0.043333
# 2005-05-01           0.066667     -0.080  ...                 0.133333
# 2005-06-01           0.396667     -0.007  ...                 0.066667
# ...                       ...        ...  ...                      ...
# 2024-04-01           0.166667      0.191  ...                -0.430000
# 2024-05-01          -0.086667     -0.008  ...                 0.166667
# 2024-06-01           0.546667     -0.149  ...                -0.086667
# 2024-07-01           0.443333      0.024  ...                 0.546667
# 2024-08-01          -0.083333     -0.093  ...                 0.443333
#
#             Electricity Price_lag_2  month  year     month_sin     month_cos  \
# DATE
# 2005-02-01                 0.153333      2  2005  8.660254e-01  5.000000e-01
# 2005-03-01                 0.153333      3  2005  1.000000e+00  6.123234e-17
# 2005-04-01                 0.153333      4  2005  8.660254e-01 -5.000000e-01
# 2005-05-01                -0.043333      5  2005  5.000000e-01 -8.660254e-01
# 2005-06-01                 0.133333      6  2005  1.224647e-16 -1.000000e+00
# ...                             ...    ...   ...           ...           ...
# 2024-04-01                 0.096667      4  2024  8.660254e-01 -5.000000e-01
# 2024-05-01                -0.430000      5  2024  5.000000e-01 -8.660254e-01
# 2024-06-01                 0.166667      6  2024  1.224647e-16 -1.000000e+00
# 2024-07-01                -0.086667      7  2024 -5.000000e-01 -8.660254e-01
# 2024-08-01                 0.546667      8  2024 -8.660254e-01 -5.000000e-01
#
#                 year_sin  year_cos  \
# DATE
# 2005-02-01 -5.894828e-02  0.998261
# 2005-03-01 -5.894828e-02  0.998261
# 2005-04-01 -5.894828e-02  0.998261
# 2005-05-01 -5.894828e-02  0.998261
# 2005-06-01 -5.894828e-02  0.998261
# ...                  ...       ...
# 2024-04-01 -2.449294e-16  1.000000
# 2024-05-01 -2.449294e-16  1.000000
# 2024-06-01 -2.449294e-16  1.000000
# 2024-07-01 -2.449294e-16  1.000000
# 2024-08-01 -2.449294e-16  1.000000
#
#             Food and Beverages CPI (target)_window_3_mean  \
# DATE
# 2005-02-01                                       0.566667
# 2005-03-01                                       0.566667
# 2005-04-01                                       0.566667
# 2005-05-01                                       0.566667
# 2005-06-01                                       0.600000
# ...                                                   ...
# 2024-04-01                                       0.538667
# 2024-05-01                                       0.147000
# 2024-06-01                                       0.278333
# 2024-07-01                                       0.431667
# 2024-08-01                                       0.594000
#
#             Food and Beverages CPI (target)_window_3_std
# DATE
# 2005-02-01                                      0.568624
# 2005-03-01                                      0.568624
# 2005-04-01                                      0.568624
# 2005-05-01                                      0.568624
# 2005-06-01                                      0.529150
# ...                                                  ...
# 2024-04-01                                      0.619253
# 2024-05-01                                      0.155936
# 2024-06-01                                      0.197548
# 2024-07-01                                      0.363243
# 2024-08-01                                      0.174605
#
# [235 rows x 84 columns]

# %%
tscv = TimeSeriesSplit(n_splits=9)
# diff_y = differencing(Y, 1)
new_Y = Y[1:]
split_index = -12
X_train = mean_only_X[1:split_index]
X_test = mean_only_X[split_index:]
y_train = diff_y[:split_index]
y_test = diff_y[split_index:]


param_grid = {
    'n_estimators': [500, 600 ,1000],     # Number of trees
    # ',              # Maximum depth of each tree
    'learning_rate': [0.01, 0.1, 0.2, 0.5],  # Step size shrinkage
    'subsample': [0.8, 1.0],             # Fraction of samples for training each tree
    'colsample_bytree': [0.8, 1.0],      # Fraction of features for each tree,
}

# Define the model
model = XGBRegressor()

# Define MSE as the scoring metric
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# Set up GridSearchCV with TimeSeriesSplit
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring={'MSE': mse_scorer, 'MAE': mae_scorer},
    cv=tscv,
    n_jobs=-1,        # Use all available cores
    verbose=1,
    refit='MSE',
)

# Fit GridSearchCV to find the best parameters
grid_search.fit(X_train, y_train)

results = pd.DataFrame(grid_search.cv_results_)
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

split_mse_cols = [col for col in results.columns if 'split' in col and 'MSE' in col]
split_mae_cols = [col for col in results.columns if 'split' in col and 'MAE' in col]

best_index = results[results.rank_test_MSE == 1].index
mse_changes = -np.ravel(results.loc[best_index, split_mse_cols].values)
mae_changes = -np.ravel(results.loc[best_index, split_mae_cols].values)

print("Average MSE across folds:", np.mean(mse_changes))
print("Average MAE across folds:", np.mean(mae_changes))

test_mse = mean_squared_error(y_test, best_model.predict(X_test))
test_mae = mean_absolute_error(y_test, best_model.predict(X_test))
print("Test MSE: ", test_mse)
print("Test MAE: ", test_mse)
# Out:
# Fitting 9 folds for each of 48 candidates, totalling 432 fits
# Average MSE across folds: 0.3839815302609059
# Average MAE across folds: 0.44859582846442514
# Test MSE:  0.12398380308067837
# Test MAE:  0.12398380308067837

# %%
fig = make_subplots(1, 2, subplot_titles=["Best model MSE", "Best model MAE"])

fig.add_trace(
    go.Scatter(y=mse_changes, name='MSE'),
              row=1, 
              col=1)

fig.add_trace(
    go.Scatter(x=[0, len(mse_changes)-1], y=[test_mse, test_mse], name='Test MSE', mode='lines', line=dict(dash='dash')),
    row=1, 
    col=1
)

fig.add_trace(
    go.Scatter(x=[0, len(mse_changes)-1], y=[np.mean(mse_changes), np.mean(mse_changes)], name='Avg training MSE', mode='lines', line=dict(dash='dash', color='orange')),
    row=1, 
    col=1
)


fig.add_trace(
    go.Scatter(y=mae_changes, name='MAE'), 
              row=1, 
              col=2)

fig.add_trace(
    go.Scatter(x=[0, len(mae_changes)-1], y=[test_mae, test_mae], name='Test MAE', mode='lines', line=dict(dash='dash', color='red')),
    row=1, 
    col=2
)

fig.add_trace(
    go.Scatter(x=[0, len(mae_changes)-1], y=[np.mean(mae_changes), np.mean(mae_changes)], name='Avg training MSE', mode='lines', line=dict(dash='dash', color='orange')),
    row=1, 
    col=2
)

fig.update_layout(
    width=1280, 
    height=640, 
    title='Best model with parameter: ' + 
          # f"learning_rate={best_params['learning_rate']}, 
          # f"learning_rate={best_params['learning_rate']}, "
          # f"max_depth={best_params['max_depth']}, "
          f"n_estimators={best_params['n_estimators']}",
)
fig.write_image(os.path.join(plot_folder, 'MSE_and_MAE_of_best_XGBoost_model.png'))
fig.show()

# %%
xg_boost_model = model.fit(X_train, y_train)
y_predicted = xg_boost_model.predict(X_test)

y_predicted = pd.Series(data=y_predicted, index=y_test.index)

plt.figure(figsize=(10,10))
plt.plot(y_test)
plt.plot(y_predicted)
plt.title('XG Boost Prediction on test set vs real value')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(os.path.join(plot_folder, 'XG_Boost_prediction'))
# y_test

# %%
explainer = shap.TreeExplainer(best_model)
explanation = explainer(X_test)

y_predicted = best_model.predict(X_test)

shap_values = explanation.values
print("Max difference", np.abs(shap_values.sum(axis=1) + explanation.base_values - y_predicted).max())

fig = plt.figure(figsize=(10, len(X_test.columns) * 0.2)) 
shap.plots.beeswarm(explanation, show=False)
plt.savefig(os.path.join(plot_folder, 'SHAP_plot.png'), bbox_inches='tight')
# Out:
# Max difference 1.3113022e-06

# %%
corr = X.corr()
plt.figure(figsize=(8,5))
sns.heatmap(corr, cmap='turbo')
plt.title('Heatmap of pairwise correlation')
plt.savefig(os.path.join(plot_folder, 'Corr_heatmap.png'), bbox_inches='tight')

# %% [markdown]
# ### LSTM Approach

# %%
scaler = MinMaxScaler()
def create_sequences(data, target, seq_length):
    data_scaled = scaler.fit_transform(data)
    # target = scaler.fit_transform(target)
    X = []
    y = []
    
    for i in range(len(data_scaled) - seq_length):
        # Collect sequences across all features (except target) for each time step
        X.append(data_scaled[i:i+seq_length, :-1]) # All columns except the last one for X
        y.append(target[i+seq_length]) # Target value from the last column at each sequence end
    
    return np.array(X), np.array(y)

sequenced_X, sequenced_y = create_sequences(mean_only_X, diff_y, 9) 


# sequenced_X = scaler.fit_transform(sequenced_X)
# for dim in sequenced_X:
#     sequenced_X[dim] = scaler.fit_transform(sequenced_X[dim])
sequenced_X.shape
# Out:
# /tmp/ipykernel_87093/2899642406.py:11: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 15
#      11         y.append(target[i+seq_length]) # Target value from the last column at each sequence end
#      13     return np.array(X), np.array(y)
# ---> 15 sequenced_X, sequenced_y = create_sequences(mean_only_X, diff_y, 9)
#      18 # sequenced_X = scaler.fit_transform(sequenced_X)
#      19 # for dim in sequenced_X:
#      20 #     sequenced_X[dim] = scaler.fit_transform(sequenced_X[dim])
#      21 sequenced_X.shape
#
# Cell In[46], line 11, in create_sequences(data, target, seq_length)
#       8 for i in range(len(data_scaled) - seq_length):
#       9     # Collect sequences across all features (except target) for each time step
#      10     X.append(data_scaled[i:i+seq_length, :-1]) # All columns except the last one for X
# ---> 11     y.append(target[i+seq_length]) # Target value from the last column at each sequence end
#      13 return np.array(X), np.array(y)
#
# File ~/miniconda3/envs/cs163/lib/python3.12/site-packages/pandas/core/series.py:1118, in Series.__getitem__(self, key)
#    1108 if is_integer(key) and self.index._should_fallback_to_positional:
#    1109     warnings.warn(
#    1110         # GH#50617
#    1111         "Series.__getitem__ treating keys as positions is deprecated. "
#    (...)
#    1116         stacklevel=find_stack_level(),
#    1117     )
# -> 1118     return self._values[key]
#    1120 elif key_is_scalar:
#    1121     return self._get_value(key)
#
# IndexError: index 235 is out of bounds for axis 0 with size 235

# %%
X_train, X_test, y_train, y_test = train_test_split(sequenced_X, sequenced_y, test_size=0.2, random_state=42, shuffle=False)

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=24, return_sequences=False, input_shape=(X_train.shape[1], X_train.shape[2])),
    
    # tf.keras.layers.LSTM(units=64, .return_sequences=False),
    
    # tf.keras.layers.LSTM(units=32, return_sequences=False),

    
    tf.keras.layers.Dense(units=64, activation='relu'),
    tf.keras.layers.Dense(1) 
])


model.compile(optimizer='adam', loss='mse')
model.summary()

# %%
history = model.fit(X_train, y_train, epochs=200)

y_predicted = model.predict(X_test)

mse = mean_squared_error(y_test, y_predicted)
mae = mean_absolute_error(y_test, y_predicted)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_predicted)

# Display additional results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Learning Curve')
plt.legend()
plt.grid(True)
plt.show()
