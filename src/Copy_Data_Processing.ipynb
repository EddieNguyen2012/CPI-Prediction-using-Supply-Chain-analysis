# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go
from datetime import datetime
import seaborn as sns

import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller, acf, pacf, ccf
from statsmodels.tsa.seasonal import STL
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, plot_ccf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, TimeSeriesSplit
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from feature_engine.creation import  CyclicalFeatures
from feature_engine.timeseries.forecasting import LagFeatures, WindowFeatures

from xgboost import XGBRegressor
import os
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
import kaleido
import plotly.io as pio
import scipy.stats as stats
import tensorflow as tf
from xgboost import DMatrix
import shap

# %%
plot_folder = '/Users/eddie/cs163/src/Plots'
data_folder = '/Users/eddie/cs163/src/Data'
pio.renderers.default = 'png'

def replace_with_underscore(x):
    return x.replace(' ', '_')

# %%
df = pd.read_csv('/Users/eddie/cs163/src/Data/final.csv', index_col=['DATE'], parse_dates=['DATE'], )
df = df.asfreq('MS')
df['month'] = df.index.month
df['year'] = df.index.year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 24 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Food and Beverages CPI (target)                  236 non-null    float64
#  7   Civilian workers Total compensation              236 non-null    float64
#  8   Private industry workers Total compensation      236 non-null    float64
#  9   State and government workers Total compensation  236 non-null    float64
#  10  DAIRY PRODUCT TOTALS                             236 non-null    float64
#  11  FIELD CROPS, OTHER                               236 non-null    float64
#  12  FOOD FISH                                        69 non-null     float64
#  13  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  14  HORTICULTURE TOTALS                              69 non-null     float64
#  15  LIVESTOCK TOTALS                                 236 non-null    float64
#  16  POULTRY TOTALS                                   236 non-null    float64
#  17  VEGETABLE TOTALS                                 236 non-null    float64
#  18  Gas Price                                        236 non-null    float64
#  19  Commercial Electricity Price                     236 non-null    float64
#  20  Industrial Electricity Price                     236 non-null    float64
#  21  Transportation Electricity Price                 236 non-null    float64
#  22  month                                            236 non-null    int32
#  23  year                                             236 non-null    int32
# dtypes: float64(22), int32(2)
# memory usage: 44.2 KB

# %%
Y = df.iloc[:, 6]
X = df[[c for c in df.columns if c not in ['Food and Beverages CPI (target)']]]

# %%
np.mean(X.iloc[0,:])
# Out:
# 153.67642857142857

# %% [markdown]
# ### Averaging and getting the mean of each index

# %%
def mean_index(data, name):
    nrow, ncol = data.shape
    avg = []
    for row in range(nrow):
        avg.append(np.mean(data.iloc[row,:]))
    return pd.Series(avg, index=data.index, name=name)

mean_only_X = pd.DataFrame(index=X.index)
# mean_only_X['PPI'] = mean_index(X.iloc[:,:6], 'PPI')
mean_only_X[X.iloc[:,:6].columns] = X.iloc[:,:6]
mean_only_X['CE'] = mean_index(X.iloc[:,6:9], 'CE')
mean_only_X['RPI'] = mean_index(X.iloc[:,9:], 'RPI')
mean_only_X['Electricity Price'] = mean_index(X.iloc[:,18:21], 'Electricity Price')
mean_only_X['Gas Price'] = X['Gas Price']

diff_mean_only_X = pd.DataFrame(index=X.index)
# diff_mean_only_X['PPI'] = mean_index(X.iloc[:,:6], 'PPI').diff()
diff_mean_only_X[X.iloc[:,:6].columns] = X.iloc[:,:6].diff()
diff_mean_only_X['CE'] = mean_index(X.iloc[:,6:9], 'CE').diff()
diff_mean_only_X['RPI'] = mean_index(X.iloc[:,9:], 'RPI').diff()
diff_mean_only_X['Electricity Price'] = mean_index(X.iloc[:,18:21], 'Electricity Price').diff()
diff_mean_only_X['Gas Price'] = X['Gas Price'].diff()
diff_mean_only_X.dropna(inplace=True)

diff_y = Y.diff()
diff_y.dropna(inplace=True)

# %%
diff_mean_only_df = diff_mean_only_X.iloc[:,:]
diff_mean_only_df['CPI'] = diff_y
px.line(diff_mean_only_df, width=1280, height=640)

# %%
mean_only_df_vif = diff_mean_only_df # Adds intercept

# Calculate VIF for each predictor
vif_data = pd.DataFrame()
vif_data['Variable'] = mean_only_df_vif.columns
vif_data['VIF'] = [variance_inflation_factor(mean_only_df_vif.values, i) for i in range(mean_only_df_vif.shape[1])]
vif_data
# Out:
#                                        Variable       VIF
# 0                 Frozen Food Manufacturing PPI  1.232552
# 1   Dried and dehydrated Food Manufacturing PPI  1.387089
# 2          Seafood Production and Packaging PPI  1.215888
# 3                  Snack Food Manufacturing PPI  1.231758
# 4             Perishable Food Manufacturing PPI  1.067939
# 5              Food and Beverages Retailers PPI  1.142272
# 6                                            CE  1.085985
# 7                                           RPI  1.180559
# 8                             Electricity Price  1.109627
# 9                                     Gas Price  1.157441
# 10                                          CPI  1.598414

# %%
for column in diff_mean_only_X.columns:
    print(column , ' :', stats.shapiro(diff_mean_only_X[column]))
# Out:
# Frozen Food Manufacturing PPI  : ShapiroResult(statistic=0.7326894551886755, pvalue=3.4565053647348475e-19)
# Dried and dehydrated Food Manufacturing PPI  : ShapiroResult(statistic=0.8365219918597775, pvalue=5.141468716660006e-15)
# Seafood Production and Packaging PPI  : ShapiroResult(statistic=0.9527796076183269, pvalue=6.012654370205769e-07)
# Snack Food Manufacturing PPI  : ShapiroResult(statistic=0.7057086770584114, pvalue=4.5446400056928515e-20)
# Perishable Food Manufacturing PPI  : ShapiroResult(statistic=0.6458799005682461, pvalue=7.97172335169679e-22)
# Food and Beverages Retailers PPI  : ShapiroResult(statistic=0.9844788172600474, pvalue=0.011468321087542177)
# CE  : ShapiroResult(statistic=0.6670475077549789, pvalue=3.1272582636715557e-21)
# RPI  : ShapiroResult(statistic=0.8443015669176146, pvalue=1.2429423937139682e-14)
# Electricity Price  : ShapiroResult(statistic=0.9788379020072603, pvalue=0.0013787618681688294)
# Gas Price  : ShapiroResult(statistic=0.9551356166014994, pvalue=1.0871824834178518e-06)

# %% [markdown]
# ### KNN Imputation for Fish Food and Horticulture

# %%
imputer = KNNImputer(n_neighbors=7)
# scaler = StandardScaler()
RPI_df = X.iloc[:,9:-2]
# RPI_df = pd.DataFrame(scaler.fit_transform(RPI_df), columns=RPI_df.columns, index=X.index)
RPI_df_imputed = pd.DataFrame(imputer.fit_transform(RPI_df), columns=RPI_df.columns, index=X.index)

for column in ['FOOD FISH', 'HORTICULTURE TOTALS']:
    data = pd.DataFrame({
        'Pre Imputed': RPI_df[column], 
        'Imputed': RPI_df_imputed[column]
    }, index=X.index)
    data_melted = data.melt(var_name='Type', value_name='Value', ignore_index=False)
    fig = px.box(data_melted, title='Pre Imputed vs Imputed ' + column, x = 'Type', y = 'Value')
    fig.write_image(os.path.join(plot_folder,'KNN_Imputed_boxplot_for_' + replace_with_underscore(column) + '.png'), width=1280, height=640)
    fig.show()
    
RPI_df_imputed_melted = RPI_df_imputed.melt(value_name='Value', var_name='Commodity', ignore_index=False)
# RPI_df_imputed_melted = RPI_df_imputed_melted[RPI_df_imputed_melted['Commodity'].isin(['FOOD FISH', 'HORTICULTURE TOTALS'])]
fig = px.line(RPI_df_imputed_melted, x=RPI_df_imputed_melted.index, y='Value', color='Commodity')
fig.write_image(os.path.join(plot_folder,'Imputed_RPI_timeseries.png'), width=1280, height=640)
fig.show()

# %% [markdown]
# After the imputation, the data for FOOD FISH and HORTICULTURE appear to maintain the normal distribution but have new outliers. However, based on the timeseries line plot with other commodities RPI, the outliers are reasonable because other indices also have strong outliers at these periods. So, we can use the imputed data for further analysis.

# %%
# Update newly imputed values
X.update(RPI_df_imputed)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Civilian workers Total compensation              236 non-null    float64
#  7   Private industry workers Total compensation      236 non-null    float64
#  8   State and government workers Total compensation  236 non-null    float64
#  9   DAIRY PRODUCT TOTALS                             236 non-null    float64
#  10  FIELD CROPS, OTHER                               236 non-null    float64
#  11  FOOD FISH                                        236 non-null    float64
#  12  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  13  HORTICULTURE TOTALS                              236 non-null    float64
#  14  LIVESTOCK TOTALS                                 236 non-null    float64
#  15  POULTRY TOTALS                                   236 non-null    float64
#  16  VEGETABLE TOTALS                                 236 non-null    float64
#  17  Gas Price                                        236 non-null    float64
#  18  Commercial Electricity Price                     236 non-null    float64
#  19  Industrial Electricity Price                     236 non-null    float64
#  20  Transportation Electricity Price                 236 non-null    float64
#  21  month                                            236 non-null    int32
#  22  year                                             236 non-null    int32
# dtypes: float64(21), int32(2)
# memory usage: 42.4 KB

# %% [markdown]
# #### Consumer Expenditures Imputation
#
# Since CE data is 2 months behind others, we will also use KNN Imputation to fill the missing value for them. Notes that this is only 2/236 so it should not affect the distribution.

# %%
imputer = KNNImputer(n_neighbors=5)
X = pd.DataFrame(imputer.fit_transform(X), columns=X.columns, index=X.index)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 236 entries, 2005-01-01 to 2024-08-01
# Freq: MS
# Data columns (total 23 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Frozen Food Manufacturing PPI                    236 non-null    float64
#  1   Dried and dehydrated Food Manufacturing PPI      236 non-null    float64
#  2   Seafood Production and Packaging PPI             236 non-null    float64
#  3   Snack Food Manufacturing PPI                     236 non-null    float64
#  4   Perishable Food Manufacturing PPI                236 non-null    float64
#  5   Food and Beverages Retailers PPI                 236 non-null    float64
#  6   Civilian workers Total compensation              236 non-null    float64
#  7   Private industry workers Total compensation      236 non-null    float64
#  8   State and government workers Total compensation  236 non-null    float64
#  9   DAIRY PRODUCT TOTALS                             236 non-null    float64
#  10  FIELD CROPS, OTHER                               236 non-null    float64
#  11  FOOD FISH                                        236 non-null    float64
#  12  FRUIT & TREE NUT TOTALS                          236 non-null    float64
#  13  HORTICULTURE TOTALS                              236 non-null    float64
#  14  LIVESTOCK TOTALS                                 236 non-null    float64
#  15  POULTRY TOTALS                                   236 non-null    float64
#  16  VEGETABLE TOTALS                                 236 non-null    float64
#  17  Gas Price                                        236 non-null    float64
#  18  Commercial Electricity Price                     236 non-null    float64
#  19  Industrial Electricity Price                     236 non-null    float64
#  20  Transportation Electricity Price                 236 non-null    float64
#  21  month                                            236 non-null    float64
#  22  year                                             236 non-null    float64
# dtypes: float64(23)
# memory usage: 44.2 KB

# %% [markdown]
# # Timeseries features engineering
#
# ## Feature lags
# ### Define function

# %%
# def create_lag_features(df, lags, features= []):
#     lag_f = LagFeatures(periods=lags)
#     if isinstance(df, pd.Series):
#         res_df = lag_f.fit_transform(pd.DataFrame(df)).iloc[:,1:].fillna(method='bfill')
#         return res_df
#     elif isinstance(df, pd.DataFrame):
#         res_df = lag_f.fit_transform(df[features]).iloc[:,len(features):].fillna(method='bfill')
#         return res_df
    
def create_lag_features(df, lags, features= []):
    lag_f = LagFeatures(periods=lags)
    if isinstance(df, pd.Series):
        res_df = lag_f.fit_transform(pd.DataFrame(df)).iloc[:,1:]
        return res_df
    elif isinstance(df, pd.DataFrame):
        res_df = lag_f.fit_transform(df[features]).iloc[:,len(features):]
        return res_df

# %% [markdown]
# ### Feature selection using Cross-correlation plot

# %%
features = diff_mean_only_X.columns
nrow = 4
ncol = 3

fig, axs = plt.subplots(nrows=nrow, ncols=ncol, figsize=(13,8))

# Flatten the axs array for easier indexing in a loop
axs = axs.flatten()

for i in range(len(features)):
    plot_ccf(diff_mean_only_X[features[i]], diff_y, title='Change of ' + features[i] + '\nvs change of CPI', ax=axs[i], negative_lags=True, alpha=0.05)

# Hide any unused subplots if there are fewer features than subplots
for j in range(len(features), len(axs)):
    axs[j].set_visible(False)

# plt.suptitle('Cross-correlation plots of the changes of all variables to changes of CPI')
plt.tight_layout()
plt.suptitle('Cross-correlation plots', y=1.05)
plt.savefig(os.path.join(plot_folder, 'CCF_of_diff_features_vs_diff_CPI.png'))
plt.show()

# %%
def find_best_lag_of_columns(data, target):
    result = []
    
    for column in data.columns:
        tmp = []
        # Calculate cross-correlation
        res = ccf(data[column], target, nlags=9)
        
        # Linear search for significant lags (cut-off at 95% confidence level)
        for i in range(1, len(res)):
            if np.abs(res[i]) > 0.05:
                tmp.append(i)
            else:
                 break
        if len(tmp) > 0:
            result.append(tmp)
        
    return result, data.columns[:len(result)]

# %%
res, cols = find_best_lag_of_columns(diff_mean_only_X.iloc[:, :-1], diff_y)
for i in range(len(cols)):
    tmp = create_lag_features(diff_mean_only_df[cols[i]], lags=res[i])
    diff_mean_only_X[tmp.columns] = tmp
diff_mean_only_X
# Out:
# /Users/eddie/miniconda3/envs/cs163/lib/python3.12/site-packages/scipy/signal/_signaltools.py:247: RuntimeWarning:
#
# Use of fft convolution on input with NAN or inf results in NAN or inf output. Consider using method='direct' instead.
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...
# 2005-03-01          -0.043333      0.167  ...
# 2005-04-01           0.133333      0.165  ...
# 2005-05-01           0.066667     -0.080  ...
# 2005-06-01           0.396667     -0.007  ...
# ...                       ...        ...  ...
# 2024-04-01           0.166667      0.191  ...
# 2024-05-01          -0.086667     -0.008  ...
# 2024-06-01           0.546667     -0.149  ...
# 2024-07-01           0.443333      0.024  ...
# 2024-08-01          -0.083333     -0.093  ...
#
#             Food and Beverages CPI (target)_window_3_mean  \
# DATE
# 2005-02-01                                     189.866667
# 2005-03-01                                     189.866667
# 2005-04-01                                     189.866667
# 2005-05-01                                     189.866667
# 2005-06-01                                     190.466667
# ...                                                   ...
# 2024-04-01                                     325.409333
# 2024-05-01                                     325.556333
# 2024-06-01                                     325.834667
# 2024-07-01                                     326.266333
# 2024-08-01                                     326.860333
#
#             Food and Beverages CPI (target)_window_3_std  Gas Price_lag_1  \
# DATE
# 2005-02-01                                      0.832666              NaN
# 2005-03-01                                      0.832666            0.078
# 2005-04-01                                      0.832666            0.167
# 2005-05-01                                      0.832666            0.165
# 2005-06-01                                      0.757188           -0.080
# ...                                                  ...              ...
# 2024-04-01                                      0.205807            0.214
# 2024-05-01                                      0.208644            0.191
# 2024-06-01                                      0.277367           -0.008
# 2024-07-01                                      0.624758           -0.149
# 2024-08-01                                      0.671056            0.024
#
#             Gas Price_lag_2  Gas Price_lag_3  Gas Price_lag_4  \
# DATE
# 2005-02-01              NaN              NaN              NaN
# 2005-03-01              NaN              NaN              NaN
# 2005-04-01            0.078              NaN              NaN
# 2005-05-01            0.167            0.078              NaN
# 2005-06-01            0.165            0.167            0.078
# ...                     ...              ...              ...
# 2024-04-01            0.131           -0.060           -0.186
# 2024-05-01            0.214            0.131           -0.060
# 2024-06-01            0.191            0.214            0.131
# 2024-07-01           -0.008            0.191            0.214
# 2024-08-01           -0.149           -0.008            0.191
#
#             Gas Price_lag_5  Gas Price_lag_6  Gas Price_lag_7  Gas Price_lag_8
# DATE
# 2005-02-01              NaN              NaN              NaN              NaN
# 2005-03-01              NaN              NaN              NaN              NaN
# 2005-04-01              NaN              NaN              NaN              NaN
# 2005-05-01              NaN              NaN              NaN              NaN
# 2005-06-01              NaN              NaN              NaN              NaN
# ...                     ...              ...              ...              ...
# 2024-04-01           -0.299           -0.216            0.004            0.242
# 2024-05-01           -0.186           -0.299           -0.216            0.004
# 2024-06-01           -0.060           -0.186           -0.299           -0.216
# 2024-07-01            0.131           -0.060           -0.186           -0.299
# 2024-08-01            0.214            0.131           -0.060           -0.186
#
# [235 rows x 63 columns]

# %% [markdown]
# The plots shows that the changes of PPI indices (except Perishable Food), and CE indices from previous lags has significant impacts on CPI. So, we will create lags features accordingly

# %% [markdown]
# ## Cyclical features

# %%
def cyclical_features(df, features):
    cycler = CyclicalFeatures()
    return cycler.fit_transform(df[features]).iloc[:,2:]

# %%
time_features = ['month', 'year']
diff_mean_only_X['month'] = diff_mean_only_X.index.month
diff_mean_only_X['year'] = diff_mean_only_X.index.year
cyc_data = cyclical_features(diff_mean_only_X, time_features)
diff_mean_only_X[cyc_data.columns] = cyc_data
# diff_mean_only_X.drop(columns=['year'], inplace=True)

# %%
diff_mean_only_X
# Out:
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  Gas Price_lag_5  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...              NaN
# 2005-03-01          -0.043333      0.167  ...              NaN
# 2005-04-01           0.133333      0.165  ...              NaN
# 2005-05-01           0.066667     -0.080  ...              NaN
# 2005-06-01           0.396667     -0.007  ...              NaN
# ...                       ...        ...  ...              ...
# 2024-04-01           0.166667      0.191  ...           -0.299
# 2024-05-01          -0.086667     -0.008  ...           -0.186
# 2024-06-01           0.546667     -0.149  ...           -0.060
# 2024-07-01           0.443333      0.024  ...            0.131
# 2024-08-01          -0.083333     -0.093  ...            0.214
#
#             Gas Price_lag_6  Gas Price_lag_7  Gas Price_lag_8  month  year  \
# DATE
# 2005-02-01              NaN              NaN              NaN      2  2005
# 2005-03-01              NaN              NaN              NaN      3  2005
# 2005-04-01              NaN              NaN              NaN      4  2005
# 2005-05-01              NaN              NaN              NaN      5  2005
# 2005-06-01              NaN              NaN              NaN      6  2005
# ...                     ...              ...              ...    ...   ...
# 2024-04-01           -0.216            0.004            0.242      4  2024
# 2024-05-01           -0.299           -0.216            0.004      5  2024
# 2024-06-01           -0.186           -0.299           -0.216      6  2024
# 2024-07-01           -0.060           -0.186           -0.299      7  2024
# 2024-08-01            0.131           -0.060           -0.186      8  2024
#
#                month_sin     month_cos      year_sin  year_cos
# DATE
# 2005-02-01  8.660254e-01  5.000000e-01 -5.894828e-02  0.998261
# 2005-03-01  1.000000e+00  6.123234e-17 -5.894828e-02  0.998261
# 2005-04-01  8.660254e-01 -5.000000e-01 -5.894828e-02  0.998261
# 2005-05-01  5.000000e-01 -8.660254e-01 -5.894828e-02  0.998261
# 2005-06-01  1.224647e-16 -1.000000e+00 -5.894828e-02  0.998261
# ...                  ...           ...           ...       ...
# 2024-04-01  8.660254e-01 -5.000000e-01 -2.449294e-16  1.000000
# 2024-05-01  5.000000e-01 -8.660254e-01 -2.449294e-16  1.000000
# 2024-06-01  1.224647e-16 -1.000000e+00 -2.449294e-16  1.000000
# 2024-07-01 -5.000000e-01 -8.660254e-01 -2.449294e-16  1.000000
# 2024-08-01 -8.660254e-01 -5.000000e-01 -2.449294e-16  1.000000
#
# [235 rows x 69 columns]

# %% [markdown]
# ## Data Windowing

# %%
windower = WindowFeatures(window=3, functions=['mean', 'std'])
windowed_Y = windower.fit_transform(pd.DataFrame(Y, 
                                                 columns=[diff_y.name], 
                                                 index=diff_y.index))
windowed_Y = windowed_Y.fillna(method='bfill').iloc[:,-2:]
diff_mean_only_X[windowed_Y.columns] = windowed_Y
diff_mean_only_X[windowed_Y.columns] = windowed_Y
# Out:
# /tmp/ipykernel_87093/2245045364.py:5: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %%
diff_mean_only_X.dropna(inplace=True)

# %% [markdown]
# ## Effect to CPI by RPI Commodity/ CE Worker segment/ PPI Industry using ARIMA with eXogenous variables (ARIMAX)

# %%
RPI_df = X.iloc[:, 9:].copy()
CE_df = X.iloc[:, 6:9].copy()
PPI_df = X.iloc[:, :6].copy()
category = [RPI_df, CE_df, PPI_df]

# %% [markdown]
# ### Assumption check
#
# #### Stationary of CPI
#
# As we saw in the EDA time series plot of CPI, it is not stationary. So, we will use differencing and use Augmented Dick-Fuller test to determine the level of differencing needed for ARIMAX. Let the threshold be 0.05, our null hypothesis is the time-series has a unit root, which is non-stationary.

# %%
def differencing(X, d):
    X_new = X.values
    for i in range(d):
        X_tmp = np.array(np.zeros(len(X)))
        for index in range(1, len(X)):
            X_tmp[index] = X_new[index] - X_new[index - 1]
        X_new = X_tmp
    
    return pd.Series(X_new, index=X.index)

# %%
adf_test = adfuller(Y)
print(f'ADF Statistic: {adf_test[0]}, p-value: {adf_test[1]}')
# Out:
# ADF Statistic: 0.45283048046851143, p-value: 0.9833666646610939

# %% [markdown]
# Originally, p-value is 0.99 > 0.05. So, we cannot reject the null hypothesis yet and transformation is needed. We will try differencing 1 time.

# %%
for d in range(4):
    adf_test = adfuller(differencing(Y, d))
    print(f'Differencing level {d}: ADF Statistic: {adf_test[0]}, p-value: {adf_test[1]}')
# Out:
# Differencing level 0: ADF Statistic: 0.45283048046851143, p-value: 0.9833666646610939
# Differencing level 1: ADF Statistic: -3.113736842824391, p-value: 0.025553161970907037
# Differencing level 2: ADF Statistic: -12.569769212010181, p-value: 2.0161460645037344e-23
# Differencing level 3: ADF Statistic: -7.6590144763304435, p-value: 1.7083369734366576e-11

# %% [markdown]
# So with 1 time differencing, CPI time-series is already stationary, so we will go with ``d = 1``

# %% [markdown]
# ## Seasonality check

# %%
diff_y = Y.diff().dropna()

# %%
df_diff_seasonal_diff = np.diff(diff_y, n=12)     
 
ad_fuller_result = adfuller(df_diff_seasonal_diff)
 
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -17.355905793334415
# p-value: 5.238063205779815e-30

# %% [markdown]
# The 2 values that are 12 months apart are seasonal using seasonal differencing of degree 1

# %%
plt.plot(diff_y[:36])

# %%
decomposition = STL(differencing(Y, 2))
result = decomposition.fit()
seasonal, trend, resid = result.seasonal, result.trend, result.resid
plt.figure(figsize=(8,6))

plt.subplot(4,1,1)
plt.plot(diff_y)
plt.title('Original Series', fontsize=16)

plt.subplot(4,1,2)
plt.plot(trend)
plt.title('Trend', fontsize=16)

plt.subplot(4,1,3)
plt.plot(seasonal)
plt.title('Seasonal', fontsize=16)

plt.subplot(4,1,4)
plt.plot(resid)
plt.title('Residual', fontsize=16)

plt.tight_layout()
plt.savefig(os.path.join(plot_folder, 'Seasonality_decomposition.png'))

# %%
prediction = seasonal + trend
plt.figure(figsize=(10, 6))
plt.plot(differencing(Y, 2))
plt.plot(prediction)
plt.savefig(os.path.join(plot_folder, 'SLT_prediction.png'))

# %%
resid_mu = resid.mean()
resid_dev = resid.std()

lower = resid_mu - 3*resid_dev
upper = resid_mu + 3*resid_dev

plt.figure(figsize=(10,4))
plt.plot(resid)

plt.fill_between([datetime(2005,1,1), datetime(2024,9,1)], lower, upper, color='g', alpha=0.25, linestyle='--', linewidth=2)
plt.xlim(datetime(2005,1,1), datetime(2024,9,1))

plt.savefig(os.path.join(plot_folder, 'Anamolies_detection.png'))

# %%
anomalies = diff_y[(resid < lower) | (resid > upper)]

plt.figure(figsize=(10,4))
plt.plot(diff_y)
for year in range(2005,2024):
    plt.axvline(datetime(year,1,1), color='k', linestyle='--', alpha=0.5)
    
plt.scatter(anomalies.index, anomalies.values, color='r', marker='D')
plt.savefig(os.path.join(plot_folder, 'Anamolies_points.png'))

# %% [markdown]
# ### AR order and MA order
#
# We will perform ACF and PACF to determine the Autoregressive term and Moving Average term.

# %%
acf = plot_acf(diff_y, lags=40)
acf.savefig(os.path.join(plot_folder, 'ACF.png'))
acf.show()
pacf = plot_pacf(diff_y, lags=40)
pacf.savefig(os.path.join(plot_folder, 'PACF.png'))
pacf.show()
# Out:
# /tmp/ipykernel_87093/4003770003.py:3: UserWarning:
#
# FigureCanvasAgg is non-interactive, and thus cannot be shown
#
# /tmp/ipykernel_87093/4003770003.py:6: UserWarning:
#
# FigureCanvasAgg is non-interactive, and thus cannot be shown

# %% [markdown]
# So MA term should be 9 and AR term should be 5

# %%
from scipy.stats import probplot


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
probplot(differencing(Y, 1), plot=ax, dist='norm')
plt.savefig(os.path.join(plot_folder, 'QQ_plot_of_CPI.png'))
# scaler = StandardScaler()


# standard_Y

# %%
stat, pvalues = stats.shapiro(differencing(Y, 2))
pvalues
# Out:
# 3.679224607707663e-08

# %%
diff_y[8:]
# Out:
# DATE
# 2005-10-01    0.500
# 2005-11-01    0.600
# 2005-12-01    0.300
# 2006-01-01    0.800
# 2006-02-01    0.100
#               ...
# 2024-04-01    0.061
# 2024-05-01    0.447
# 2024-06-01    0.787
# 2024-07-01    0.548
# 2024-08-01    0.361
# Freq: MS, Name: Food and Beverages CPI (target), Length: 227, dtype: float64

# %%
start_time = diff_mean_only_X

SARIMAX_X_train = diff_mean_only_X.iloc[:-6,:]
SARIMAX_y_train = Y[9:-6]
SARIMAX_X_test = diff_mean_only_X.iloc[-6:,:]
SARIMAX_y_test = Y[-6:]

model = SARIMAX(
    endog=SARIMAX_y_train, 
    exog=SARIMAX_X_train, 
    order=(1, 1, 0), #p,d,q order
    seasonal_order=(0, 1, 1, 9),
)
results = model.fit()

print(results.summary())
results.plot_diagnostics(figsize=(10,10))
plt.savefig(os.path.join(plot_folder, 'SARIMAX_diagnosis.png'))
plt.show()


data_prediction = results.predict(exog=SARIMAX_X_train.iloc[12:], start='10-01-2006')
y_predicted = results.predict(exog= SARIMAX_X_test, start='03-01-2024', end='08-01-2024')

print('Model AIC: ', results.aic)
print('Model BIC: ', results.bic)
print('Balance: ', np.abs(results.aic - results.bic))

print('MSE on dataset: ', mean_squared_error(data_prediction, SARIMAX_y_train[12:]))
print('MAE on dataset: ', mean_squared_error(data_prediction, SARIMAX_y_train[12:]))

print('MSE on test set: ', mean_squared_error(y_predicted, SARIMAX_y_test))
print('MAE on test set: ', mean_squared_error(y_predicted, SARIMAX_y_test))
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           72     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.23964D-01    |proj g|=  3.70460D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.05011D-01    |proj g|=  1.46558D-01
#
# At iterate   10    f=  4.01221D-01    |proj g|=  9.72343D-02
#
# At iterate   15    f=  3.93525D-01    |proj g|=  5.08630D-01
#
# At iterate   20    f=  3.85629D-01    |proj g|=  9.55436D-02
#
# At iterate   25    f=  3.78372D-01    |proj g|=  8.97757D-02
#
# At iterate   30    f=  3.73650D-01    |proj g|=  2.95694D-01
#
# At iterate   35    f=  3.67988D-01    |proj g|=  7.64978D-02
#
# At iterate   40    f=  3.63600D-01    |proj g|=  7.25044D-02
#
# At iterate   45    f=  3.61105D-01    |proj g|=  1.00016D-01
# /Users/eddie/miniconda3/envs/cs163/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# At iterate   50    f=  3.58429D-01    |proj g|=  1.07692D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    72     50     56      1     0     0   1.077D-01   3.584D-01
#   F =  0.35842911818138506
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:     Food and Beverages CPI (target)   No. Observations:                  221
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 9)   Log Likelihood                 -79.213
# Date:                             Sun, 10 Nov 2024   AIC                            302.426
# Time:                                     21:26:10   BIC                            543.759
# Sample:                                 10-01-2005   HQIC                           399.978
#                                       - 02-01-2024
# Covariance Type:                               opg
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Frozen Food Manufacturing PPI                        -0.0148      0.037     -0.404      0.686      -0.087       0.057
# Dried and dehydrated Food Manufacturing PPI           0.0380      0.023      1.660      0.097      -0.007       0.083
# Seafood Production and Packaging PPI                  0.0082      0.030      0.273      0.785      -0.051       0.067
# Snack Food Manufacturing PPI                          0.0667      0.043      1.535      0.125      -0.018       0.152
# Perishable Food Manufacturing PPI                     0.0128      0.014      0.906      0.365      -0.015       0.040
# Food and Beverages Retailers PPI                     -0.0004      0.016     -0.024      0.981      -0.033       0.032
# CE                                                   -0.3240      0.293     -1.106      0.269      -0.898       0.250
# RPI                                                  -0.0229      0.018     -1.263      0.207      -0.058       0.013
# Electricity Price                                    -0.0620      0.169     -0.366      0.714      -0.394       0.270
# Gas Price                                            -0.2989      0.224     -1.334      0.182      -0.738       0.140
# Frozen Food Manufacturing PPI_lag_1                   0.0709      0.064      1.114      0.265      -0.054       0.196
# Frozen Food Manufacturing PPI_lag_2                   0.0612      0.071      0.856      0.392      -0.079       0.201
# Frozen Food Manufacturing PPI_lag_3                   0.0748      0.074      1.016      0.310      -0.070       0.219
# Frozen Food Manufacturing PPI_lag_4                   0.0617      0.077      0.803      0.422      -0.089       0.213
# Frozen Food Manufacturing PPI_lag_5                   0.1279      0.077      1.652      0.099      -0.024       0.280
# Frozen Food Manufacturing PPI_lag_6                   0.1219      0.070      1.737      0.082      -0.016       0.259
# Frozen Food Manufacturing PPI_lag_7                   0.0725      0.063      1.143      0.253      -0.052       0.197
# Frozen Food Manufacturing PPI_lag_8                  -0.0007      0.043     -0.017      0.987      -0.085       0.084
# Dried and dehydrated Food Manufacturing PPI_lag_1     0.0593      0.034      1.750      0.080      -0.007       0.126
# Dried and dehydrated Food Manufacturing PPI_lag_2     0.0323      0.041      0.792      0.428      -0.048       0.112
# Dried and dehydrated Food Manufacturing PPI_lag_3     0.0542      0.048      1.120      0.263      -0.041       0.149
# Dried and dehydrated Food Manufacturing PPI_lag_4     0.0303      0.048      0.635      0.525      -0.063       0.124
# Dried and dehydrated Food Manufacturing PPI_lag_5     0.0474      0.045      1.045      0.296      -0.041       0.136
# Dried and dehydrated Food Manufacturing PPI_lag_6     0.0403      0.041      0.995      0.320      -0.039       0.120
# Dried and dehydrated Food Manufacturing PPI_lag_7     0.0496      0.037      1.327      0.185      -0.024       0.123
# Dried and dehydrated Food Manufacturing PPI_lag_8     0.0348      0.030      1.156      0.248      -0.024       0.094
# Seafood Production and Packaging PPI_lag_1           -0.0762      0.037     -2.087      0.037      -0.148      -0.005
# Seafood Production and Packaging PPI_lag_2           -0.0626      0.040     -1.574      0.116      -0.141       0.015
# Seafood Production and Packaging PPI_lag_3           -0.0336      0.032     -1.038      0.299      -0.097       0.030
# Seafood Production and Packaging PPI_lag_4            0.0046      0.027      0.170      0.865      -0.048       0.058
# Snack Food Manufacturing PPI_lag_1                    0.0169      0.056      0.302      0.762      -0.093       0.127
# Snack Food Manufacturing PPI_lag_2                    0.0305      0.053      0.579      0.563      -0.073       0.134
# Snack Food Manufacturing PPI_lag_3                    0.0481      0.054      0.895      0.371      -0.057       0.154
# Snack Food Manufacturing PPI_lag_4                    0.0193      0.058      0.333      0.739      -0.094       0.133
# Snack Food Manufacturing PPI_lag_5                    0.0300      0.054      0.552      0.581      -0.077       0.137
# Snack Food Manufacturing PPI_lag_6                    0.0091      0.058      0.158      0.874      -0.104       0.122
# Snack Food Manufacturing PPI_lag_7                    0.0294      0.053      0.551      0.582      -0.075       0.134
# Snack Food Manufacturing PPI_lag_8                    0.0447      0.046      0.962      0.336      -0.046       0.136
# Perishable Food Manufacturing PPI_lag_1              -0.0092      0.015     -0.594      0.552      -0.039       0.021
# Food and Beverages Retailers PPI_lag_1                0.0321      0.026      1.255      0.209      -0.018       0.082
# Food and Beverages Retailers PPI_lag_2                0.0296      0.032      0.926      0.355      -0.033       0.092
# Food and Beverages Retailers PPI_lag_3                0.0376      0.037      1.011      0.312      -0.035       0.111
# Food and Beverages Retailers PPI_lag_4                0.0129      0.040      0.321      0.748      -0.066       0.092
# Food and Beverages Retailers PPI_lag_5                0.0168      0.040      0.420      0.675      -0.062       0.095
# Food and Beverages Retailers PPI_lag_6                0.0075      0.038      0.197      0.844      -0.067       0.082
# Food and Beverages Retailers PPI_lag_7                0.0205      0.028      0.720      0.471      -0.035       0.076
# Food and Beverages Retailers PPI_lag_8                0.0193      0.019      1.023      0.306      -0.018       0.056
# CE_lag_1                                             -0.2809      0.397     -0.708      0.479      -1.058       0.497
# CE_lag_2                                             -0.2903      0.338     -0.860      0.390      -0.952       0.371
# RPI_lag_1                                             0.0114      0.026      0.447      0.655      -0.039       0.062
# RPI_lag_2                                             0.0015      0.023      0.063      0.950      -0.044       0.047
# Electricity Price_lag_1                              -0.0211      0.163     -0.129      0.897      -0.340       0.298
# Electricity Price_lag_2                              -0.0767      0.172     -0.445      0.656      -0.414       0.261
# Food and Beverages CPI (target)_window_3_mean         0.7349      0.079      9.296      0.000       0.580       0.890
# Food and Beverages CPI (target)_window_3_std          0.8017      0.199      4.036      0.000       0.412       1.191
# Gas Price_lag_1                                      -0.1593      0.252     -0.633      0.527      -0.652       0.334
# Gas Price_lag_2                                      -0.0765      0.295     -0.260      0.795      -0.654       0.501
# Gas Price_lag_3                                       0.1084      0.302      0.359      0.720      -0.483       0.700
# Gas Price_lag_4                                       0.3757      0.304      1.237      0.216      -0.220       0.971
# Gas Price_lag_5                                       0.4837      0.301      1.610      0.107      -0.105       1.073
# Gas Price_lag_6                                       0.4655      0.277      1.678      0.093      -0.078       1.009
# Gas Price_lag_7                                       0.2202      0.268      0.821      0.411      -0.305       0.746
# Gas Price_lag_8                                       0.2183      0.238      0.918      0.359      -0.248       0.684
# month                                              -131.3575    246.074     -0.534      0.593    -613.653     350.938
# year                                                 10.9454   2952.898      0.004      0.997   -5776.628    5798.519
# month_sin                                             0.1052      0.156      0.673      0.501      -0.201       0.412
# month_cos                                            -0.0422      0.133     -0.318      0.750      -0.302       0.218
# year_sin                                          -5.111e+05     92.343  -5535.218      0.000   -5.11e+05   -5.11e+05
# year_cos                                          -1.083e+04   2744.209     -3.945      0.000   -1.62e+04   -5448.017
# ar.L1                                                -0.1393      0.162     -0.862      0.389      -0.456       0.177
# ma.S.L9                                              -0.7501      0.109     -6.908      0.000      -0.963      -0.537
# sigma2                                                0.1208      0.018      6.599      0.000       0.085       0.157
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                55.18
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.35   Skew:                             0.45
# Prob(H) (two-sided):                  0.21   Kurtosis:                         5.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.04e+18. Standard errors may be unstable.
# Model AIC:  302.4256702361722
# Model BIC:  543.759455846449
# Balance:  241.33378561027678
# MSE on dataset:  0.12468498720766315
# MAE on dataset:  0.12468498720766315
# MSE on test set:  0.22825328048290736
# MAE on test set:  0.22825328048290736

# %%
# y_predicted = results.predict(exog= SARIMAX_X_test, start='03-01-2024', end='08-01-2024')
plt.figure(figsize=(10,10))
plt.plot(SARIMAX_y_test[-7:])
plt.plot(y_predicted)
plt.scatter(y=SARIMAX_y_test[-7:], x=SARIMAX_y_test[-7:].index, marker='*')
plt.scatter(y=y_predicted, x=SARIMAX_y_test[-7:].index, marker='x')
plt.title('Predicted data vs real CPI from SARIMAX for the most recent 5 months')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(    
    os.path.join(plot_folder, 'SARIMAX_prediction.png')
)

# %%
import scipy.stats as stats

stat, pvalues = stats.shapiro(results.resid)
print('Shapiro-Wilks test p-value: ', pvalues)
# Out:
# Shapiro-Wilks test p-value:  2.1714082436116464e-31

# %%
data_prediction = results.predict(exog=SARIMAX_X_train.iloc[12:], start='01-01-2007')
plt.figure(figsize=(10,10))
plt.plot(SARIMAX_y_train.iloc[12:])
plt.plot(data_prediction)
plt.title('Predicted data vs real CPI from SARIMAX from 2006 to present')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(
    os.path.join(plot_folder, 'SARIMAX_prediction_whole_data.png')
)

# %% [markdown]
# #### ARIMAX Results

# %% [markdown]
# ### XGBoost

# %%
diff_mean_only_X
# Out:
#             Frozen Food Manufacturing PPI  \
# DATE
# 2005-02-01                         -0.100
# 2005-03-01                          0.000
# 2005-04-01                          0.100
# 2005-05-01                          0.300
# 2005-06-01                         -0.100
# ...                                   ...
# 2024-04-01                         -0.389
# 2024-05-01                          0.730
# 2024-06-01                         -0.516
# 2024-07-01                         -1.005
# 2024-08-01                          1.326
#
#             Dried and dehydrated Food Manufacturing PPI  \
# DATE
# 2005-02-01                                       -0.200
# 2005-03-01                                       -0.400
# 2005-04-01                                        0.100
# 2005-05-01                                        0.400
# 2005-06-01                                       -0.500
# ...                                                 ...
# 2024-04-01                                       -0.160
# 2024-05-01                                        2.427
# 2024-06-01                                        0.543
# 2024-07-01                                       -0.282
# 2024-08-01                                       -4.276
#
#             Seafood Production and Packaging PPI  \
# DATE
# 2005-02-01                                -1.400
# 2005-03-01                                 0.600
# 2005-04-01                                -0.100
# 2005-05-01                                 0.300
# 2005-06-01                                 0.600
# ...                                          ...
# 2024-04-01                                -0.946
# 2024-05-01                                -1.400
# 2024-06-01                                 0.125
# 2024-07-01                                 1.850
# 2024-08-01                                 0.631
#
#             Snack Food Manufacturing PPI  Perishable Food Manufacturing PPI  \
# DATE
# 2005-02-01                         0.900                              0.400
# 2005-03-01                         0.300                              0.100
# 2005-04-01                         1.100                              0.500
# 2005-05-01                         0.400                              0.800
# 2005-06-01                         0.500                             -0.800
# ...                                  ...                                ...
# 2024-04-01                        -5.111                              4.431
# 2024-05-01                        -0.199                             -1.375
# 2024-06-01                        -0.238                              1.467
# 2024-07-01                         0.038                              1.605
# 2024-08-01                         2.658                             -2.672
#
#             Food and Beverages Retailers PPI        CE       RPI  \
# DATE
# 2005-02-01                             3.100  0.000000  1.361500
# 2005-03-01                            -0.400  0.000000  2.353083
# 2005-04-01                            -1.800 -0.300000  0.672083
# 2005-05-01                             0.300  0.000000 -1.931667
# 2005-06-01                             3.400  0.000000  0.681917
# ...                                      ...       ...       ...
# 2024-04-01                            -0.404 -0.066667 -1.572071
# 2024-05-01                             2.598  0.000000 -0.383429
# 2024-06-01                            -1.544  0.000000  5.842214
# 2024-07-01                            -5.477 -0.233333 -1.467571
# 2024-08-01                            -0.972  0.000000  0.561214
#
#             Electricity Price  Gas Price  ...  Electricity Price_lag_1  \
# DATE                                      ...
# 2005-02-01           0.153333      0.078  ...                 0.153333
# 2005-03-01          -0.043333      0.167  ...                 0.153333
# 2005-04-01           0.133333      0.165  ...                -0.043333
# 2005-05-01           0.066667     -0.080  ...                 0.133333
# 2005-06-01           0.396667     -0.007  ...                 0.066667
# ...                       ...        ...  ...                      ...
# 2024-04-01           0.166667      0.191  ...                -0.430000
# 2024-05-01          -0.086667     -0.008  ...                 0.166667
# 2024-06-01           0.546667     -0.149  ...                -0.086667
# 2024-07-01           0.443333      0.024  ...                 0.546667
# 2024-08-01          -0.083333     -0.093  ...                 0.443333
#
#             Electricity Price_lag_2  month  year     month_sin     month_cos  \
# DATE
# 2005-02-01                 0.153333      2  2005  8.660254e-01  5.000000e-01
# 2005-03-01                 0.153333      3  2005  1.000000e+00  6.123234e-17
# 2005-04-01                 0.153333      4  2005  8.660254e-01 -5.000000e-01
# 2005-05-01                -0.043333      5  2005  5.000000e-01 -8.660254e-01
# 2005-06-01                 0.133333      6  2005  1.224647e-16 -1.000000e+00
# ...                             ...    ...   ...           ...           ...
# 2024-04-01                 0.096667      4  2024  8.660254e-01 -5.000000e-01
# 2024-05-01                -0.430000      5  2024  5.000000e-01 -8.660254e-01
# 2024-06-01                 0.166667      6  2024  1.224647e-16 -1.000000e+00
# 2024-07-01                -0.086667      7  2024 -5.000000e-01 -8.660254e-01
# 2024-08-01                 0.546667      8  2024 -8.660254e-01 -5.000000e-01
#
#                 year_sin  year_cos  \
# DATE
# 2005-02-01 -5.894828e-02  0.998261
# 2005-03-01 -5.894828e-02  0.998261
# 2005-04-01 -5.894828e-02  0.998261
# 2005-05-01 -5.894828e-02  0.998261
# 2005-06-01 -5.894828e-02  0.998261
# ...                  ...       ...
# 2024-04-01 -2.449294e-16  1.000000
# 2024-05-01 -2.449294e-16  1.000000
# 2024-06-01 -2.449294e-16  1.000000
# 2024-07-01 -2.449294e-16  1.000000
# 2024-08-01 -2.449294e-16  1.000000
#
#             Food and Beverages CPI (target)_window_3_mean  \
# DATE
# 2005-02-01                                       0.566667
# 2005-03-01                                       0.566667
# 2005-04-01                                       0.566667
# 2005-05-01                                       0.566667
# 2005-06-01                                       0.600000
# ...                                                   ...
# 2024-04-01                                       0.538667
# 2024-05-01                                       0.147000
# 2024-06-01                                       0.278333
# 2024-07-01                                       0.431667
# 2024-08-01                                       0.594000
#
#             Food and Beverages CPI (target)_window_3_std
# DATE
# 2005-02-01                                      0.568624
# 2005-03-01                                      0.568624
# 2005-04-01                                      0.568624
# 2005-05-01                                      0.568624
# 2005-06-01                                      0.529150
# ...                                                  ...
# 2024-04-01                                      0.619253
# 2024-05-01                                      0.155936
# 2024-06-01                                      0.197548
# 2024-07-01                                      0.363243
# 2024-08-01                                      0.174605
#
# [235 rows x 84 columns]

# %%
tscv = TimeSeriesSplit(n_splits=12)
# diff_y = differencing(Y, 1)
new_Y = Y[1:]
split_index = -12
X_train = diff_mean_only_X[1:split_index]
X_test = diff_mean_only_X[split_index:]
y_train = diff_y[9:split_index]
y_test = diff_y[split_index:]


param_grid = {
    'n_estimators': [400, 500, 600],     # Number of trees
    # ',              # Maximum depth of each tree
    'learning_rate': [0.01, 0.1, 0.2, 0.5],  # Step size shrinkage
    'subsample': [0.5, 0.8, 1.0],             # Fraction of samples for training each tree
    'colsample_bytree': [0.5, 0.8, 1.0],      # Fraction of features for each tree,
}

# Define the model
model = XGBRegressor()

# Define MSE as the scoring metric
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)
mae_scorer = make_scorer(mean_absolute_error, greater_is_better=False)

# Set up GridSearchCV with TimeSeriesSplit
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring={'MSE': mse_scorer, 'MAE': mae_scorer},
    cv=tscv,
    n_jobs=-1,        # Use all available cores
    verbose=1,
    refit='MSE',
)

# Fit GridSearchCV to find the best parameters
grid_search.fit(X_train, y_train)

results = pd.DataFrame(grid_search.cv_results_)
best_model = grid_search.best_estimator_
best_params = grid_search.best_params_

split_mse_cols = [col for col in results.columns if 'split' in col and 'MSE' in col]
split_mae_cols = [col for col in results.columns if 'split' in col and 'MAE' in col]

best_index = results[results.rank_test_MSE == 1].index
mse_changes = -np.ravel(results.loc[best_index, split_mse_cols].values)
mae_changes = -np.ravel(results.loc[best_index, split_mae_cols].values)

print("Average MSE across folds:", np.mean(mse_changes))
print("Average MAE across folds:", np.mean(mae_changes))

test_mse = mean_squared_error(y_test, best_model.predict(X_test))
test_mae = mean_absolute_error(y_test, best_model.predict(X_test))
print("Test MSE: ", test_mse)
print("Test MAE: ", test_mse)
# Out:
# Fitting 12 folds for each of 108 candidates, totalling 1296 fits
# Average MSE across folds: 0.32798245464918746
# Average MAE across folds: 0.4206556724669648
# Test MSE:  0.24036801263653837
# Test MAE:  0.24036801263653837

# %%
fig = make_subplots(1, 2, subplot_titles=["Best model MSE", "Best model MAE"])

fig.add_trace(
    go.Scatter(y=mse_changes, name='MSE'),
              row=1, 
              col=1)

fig.add_trace(
    go.Scatter(x=[0, len(mse_changes)-1], y=[test_mse, test_mse], name='Test MSE', mode='lines', line=dict(dash='dash')),
    row=1, 
    col=1
)

fig.add_trace(
    go.Scatter(x=[0, len(mse_changes)-1], y=[np.mean(mse_changes), np.mean(mse_changes)], name='Avg training MSE', mode='lines', line=dict(dash='dash', color='orange')),
    row=1, 
    col=1
)


fig.add_trace(
    go.Scatter(y=mae_changes, name='MAE'), 
              row=1, 
              col=2)

fig.add_trace(
    go.Scatter(x=[0, len(mae_changes)-1], y=[test_mae, test_mae], name='Test MAE', mode='lines', line=dict(dash='dash', color='red')),
    row=1, 
    col=2
)

fig.add_trace(
    go.Scatter(x=[0, len(mae_changes)-1], y=[np.mean(mae_changes), np.mean(mae_changes)], name='Avg training MSE', mode='lines', line=dict(dash='dash', color='orange')),
    row=1, 
    col=2
)

fig.update_layout(
    width=1280, 
    height=640, 
    title='Best model with parameter: ' + 
          # f"learning_rate={best_params['learning_rate']}, 
          # f"learning_rate={best_params['learning_rate']}, "
          # f"max_depth={best_params['max_depth']}, "
          f"n_estimators={best_params['n_estimators']}",
)
fig.write_image(os.path.join(plot_folder, 'MSE_and_MAE_of_best_XGBoost_model.png'))
fig.show()

# %%
xg_boost_model = model.fit(X_train, y_train)
y_predicted = xg_boost_model.predict(X_test)

y_predicted = pd.Series(data=y_predicted, index=y_test.index)

plt.figure(figsize=(10,10))
plt.plot(y_test)
plt.plot(y_predicted)
plt.title('XG Boost Prediction on test set vs real value')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(os.path.join(plot_folder, 'XG_Boost_prediction'))
# y_test

# %%
y_predicted = xg_boost_model.predict(X_train)

y_predicted = pd.Series(data=y_predicted, index=y_train.index)

plt.figure(figsize=(10,10))
plt.plot(y_train)
plt.plot(y_predicted)
plt.title('XG Boost Prediction on test set vs real value')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.savefig(os.path.join(plot_folder, 'XG_Boost_prediction'))
# y_test

# %%
explainer = shap.TreeExplainer(best_model)
explanation = explainer(X_test)

y_predicted = best_model.predict(X_test)

shap_values = explanation.values
print("Max difference", np.abs(shap_values.sum(axis=1) + explanation.base_values - y_predicted).max())

fig = plt.figure(figsize=(10, len(X_test.columns) * 0.2)) 
shap.plots.beeswarm(explanation, show=False)
plt.savefig(os.path.join(plot_folder, 'SHAP_plot.png'), bbox_inches='tight')
# Out:
# Max difference 5.9604645e-07

# %%
corr = diff_mean_only_df.corr()
plt.figure(figsize=(8,5))
sns.heatmap(corr, cmap='turbo')
plt.title('Heatmap of pairwise correlation')
plt.savefig(os.path.join(plot_folder, 'Corr_heatmap.png'), bbox_inches='tight')

# %% [markdown]
# ### LSTM Approach

# %%
scaler = MinMaxScaler()

def create_sequences(data, target, seq_length):
    # Scale the entire dataset and target
    data_scaled = scaler.fit_transform(data)
    target_scaled = scaler.fit_transform(target)
    print(len(data_scaled))
    X = []
    y = []
    
    for i in range(len(data_scaled) - seq_length):
        # Collect sequences across all features (except the last one for X)
        X.append(data_scaled[i:i+seq_length, :-1])
        # Target value from the last column at each sequence end
        y.append(target_scaled[i-1+seq_length])
    
    return np.array(X), np.array(y)

# Generate the sequences
sequenced_X, sequenced_y = create_sequences(diff_mean_only_X, pd.DataFrame(diff_y[9:], index=diff_y[9:].index), 12)

print("Shape of sequenced_X:", sequenced_X.shape)
print("Shape of sequenced_y:", sequenced_y.shape)
# Out:
# 227
# Shape of sequenced_X: (215, 12, 68)
# Shape of sequenced_y: (215, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(sequenced_X, sequenced_y, test_size=0.2, shuffle=False)

model = tf.keras.Sequential([
    tf.keras.layers.LSTM(units=81, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    
    # tf.keras.layers.LSTM(units=9, return_sequences=False),


    
    tf.keras.layers.LSTM(units=9, return_sequences=False),

    
    tf.keras.layers.Dense(units=9, activation='relu'),
    tf.keras.layers.Dense(1) 
])


model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# /Users/eddie/miniconda3/envs/cs163/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential_32"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_61 (LSTM)                  │ (None, 12, 81)         │        48,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_62 (LSTM)                  │ (None, 9)              │         3,276 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 9)              │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_63 (Dense)                │ (None, 1)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,976 (203.03 KB)
#  Trainable params: 51,976 (203.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=500, verbose='auto')

y_predicted = model.predict(X_test)

mse = mean_squared_error(y_test, y_predicted)
mae = mean_absolute_error(y_test, y_predicted)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_predicted)

# Display additional results
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R²):", r2)

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Learning Curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0671
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0149
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0125
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0117
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0107
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0129
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0098
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0147
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0139
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0122
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0116
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0142
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0107
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0109
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0126
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0155
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0111
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0108
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0106
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0143
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0112
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0124
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0100
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0096
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0121
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0093
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0115
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0092
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0113
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0119
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0104
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0076
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0085
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0091
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0079
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0101
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0124
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0101
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0103
# Epoch 115/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072
# Epoch 116/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0097
# Epoch 117/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0109
# Epoch 118/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060
# Epoch 119/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077
# Epoch 120/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094
# Epoch 121/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070
# Epoch 122/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0090
# Epoch 123/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085
# Epoch 124/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075
# Epoch 125/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060
# Epoch 126/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094
# Epoch 127/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070
# Epoch 128/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097
# Epoch 129/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0120
# Epoch 130/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0097
# Epoch 131/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0094
# Epoch 132/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072
# Epoch 133/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064
# Epoch 134/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070
# Epoch 135/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063
# Epoch 136/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069
# Epoch 137/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071
# Epoch 138/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078
# Epoch 139/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060
# Epoch 140/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074
# Epoch 141/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062
# Epoch 142/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086
# Epoch 143/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066
# Epoch 144/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083
# Epoch 145/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077
# Epoch 146/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055
# Epoch 147/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049
# Epoch 148/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061
# Epoch 149/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050
# Epoch 150/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061
# Epoch 151/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0094
# Epoch 152/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079
# Epoch 153/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0073
# Epoch 154/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055
# Epoch 155/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 156/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075
# Epoch 157/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 158/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068
# Epoch 159/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061
# Epoch 160/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0063
# Epoch 161/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 162/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0077
# Epoch 163/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065
# Epoch 164/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057
# Epoch 165/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072
# Epoch 166/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057
# Epoch 167/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0041
# Epoch 168/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 169/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067
# Epoch 170/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072
# Epoch 171/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0082
# Epoch 172/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0070
# Epoch 173/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068
# Epoch 174/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055
# Epoch 175/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061
# Epoch 176/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066
# Epoch 177/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0066
# Epoch 178/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0050
# Epoch 179/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053
# Epoch 180/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055
# Epoch 181/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056
# Epoch 182/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070
# Epoch 183/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060
# Epoch 184/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048
# Epoch 185/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052
# Epoch 186/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 187/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050
# Epoch 188/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 189/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040
# Epoch 190/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052
# Epoch 191/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 192/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 193/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056
# Epoch 194/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046
# Epoch 195/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039
# Epoch 196/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035
# Epoch 197/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 198/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 199/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 200/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074
# Epoch 201/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 202/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039
# Epoch 203/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 204/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040
# Epoch 205/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 206/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 207/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054
# Epoch 208/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039
# Epoch 209/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039
# Epoch 210/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0037
# Epoch 211/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 212/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 213/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040
# Epoch 214/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 215/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034
# Epoch 216/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 217/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0032
# Epoch 218/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033
# Epoch 219/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037
# Epoch 220/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037
# Epoch 221/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035
# Epoch 222/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036
# Epoch 223/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 224/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0033
# Epoch 225/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 226/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 227/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 228/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 229/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026
# Epoch 230/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 231/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025
# Epoch 232/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028
# Epoch 233/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 234/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 235/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 236/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0030
# Epoch 237/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 238/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 239/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053
# Epoch 240/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051
# Epoch 241/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0045
# Epoch 242/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0033
# Epoch 243/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0025
# Epoch 244/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034
# Epoch 245/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034
# Epoch 246/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035
# Epoch 247/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 248/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029
# Epoch 249/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 250/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 251/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 252/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 253/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 254/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 255/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 256/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 257/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 258/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 259/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 260/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0021
# Epoch 261/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023
# Epoch 262/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 263/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 264/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 265/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0018
# Epoch 266/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 267/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 268/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018
# Epoch 269/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 270/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0015
# Epoch 271/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017
# Epoch 272/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 273/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 274/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0019
# Epoch 275/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 276/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0029
# Epoch 277/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 278/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0024
# Epoch 279/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 280/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 281/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 282/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 283/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 284/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 285/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 286/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 287/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 288/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 289/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 290/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 291/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0016
# Epoch 292/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 293/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 294/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015
# Epoch 295/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 296/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 297/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 298/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013
# Epoch 299/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 300/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 301/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 302/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 303/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 304/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 305/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 306/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 307/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 308/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 309/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 310/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 311/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9102e-04
# Epoch 312/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 313/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9914e-04
# Epoch 314/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 315/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 316/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 317/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 318/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012
# Epoch 319/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011
# Epoch 320/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 321/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8304e-04
# Epoch 322/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010
# Epoch 323/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9112e-04
# Epoch 324/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1482e-04
# Epoch 325/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6980e-04
# Epoch 326/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6187e-04
# Epoch 327/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 328/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7885e-04
# Epoch 329/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0982e-04
# Epoch 330/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7183e-04
# Epoch 331/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2679e-04
# Epoch 332/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7503e-04
# Epoch 333/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1941e-04
# Epoch 334/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7483e-04
# Epoch 335/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0478e-04
# Epoch 336/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7743e-04
# Epoch 337/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7569e-04
# Epoch 338/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0010
# Epoch 339/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7971e-04
# Epoch 340/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0559e-04
# Epoch 341/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9584e-04
# Epoch 342/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3478e-04
# Epoch 343/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7136e-04
# Epoch 344/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1479e-04
# Epoch 345/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8407e-04
# Epoch 346/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0796e-04
# Epoch 347/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0619e-04
# Epoch 348/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0373e-04
# Epoch 349/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8380e-04
# Epoch 350/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1889e-04
# Epoch 351/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2711e-04
# Epoch 352/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8205e-04
# Epoch 353/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7168e-04
# Epoch 354/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9437e-04
# Epoch 355/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3769e-04
# Epoch 356/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2922e-04
# Epoch 357/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9372e-04
# Epoch 358/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4618e-04
# Epoch 359/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0098e-04
# Epoch 360/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8135e-04
# Epoch 361/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5152e-04
# Epoch 362/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 363/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4884e-04
# Epoch 364/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3961e-04
# Epoch 365/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6089e-04
# Epoch 366/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1543e-04
# Epoch 367/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0869e-04
# Epoch 368/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4841e-04
# Epoch 369/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8064e-04
# Epoch 370/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6582e-04
# Epoch 371/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6441e-04
# Epoch 372/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4974e-04
# Epoch 373/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3993e-04
# Epoch 374/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8916e-04
# Epoch 375/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4938e-04
# Epoch 376/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0493e-04
# Epoch 377/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8763e-04
# Epoch 378/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6775e-04
# Epoch 379/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6925e-04
# Epoch 380/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8033e-04
# Epoch 381/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9907e-04
# Epoch 382/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2045e-04
# Epoch 383/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3807e-04
# Epoch 384/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0870e-04
# Epoch 385/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4296e-04
# Epoch 386/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0965e-04
# Epoch 387/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5242e-04
# Epoch 388/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7250e-04
# Epoch 389/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5802e-04
# Epoch 390/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3953e-04
# Epoch 391/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1290e-04
# Epoch 392/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0003e-04
# Epoch 393/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0478e-04
# Epoch 394/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7902e-04
# Epoch 395/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0862e-04
# Epoch 396/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0862e-04
# Epoch 397/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6795e-04
# Epoch 398/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4970e-04
# Epoch 399/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7964e-04
# Epoch 400/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1658e-04
# Epoch 401/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9394e-04
# Epoch 402/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6019e-04
# Epoch 403/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6306e-04
# Epoch 404/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0745e-04
# Epoch 405/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5883e-04
# Epoch 406/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6055e-04
# Epoch 407/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3695e-04
# Epoch 408/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9223e-04
# Epoch 409/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9415e-04
# Epoch 410/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8346e-04
# Epoch 411/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1637e-04
# Epoch 412/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5962e-04
# Epoch 413/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8121e-04
# Epoch 414/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9042e-04
# Epoch 415/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3964e-04
# Epoch 416/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8636e-04
# Epoch 417/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7137e-04
# Epoch 418/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4562e-04
# Epoch 419/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2069e-04
# Epoch 420/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5056e-04
# Epoch 421/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3114e-04
# Epoch 422/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6755e-04
# Epoch 423/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8909e-04
# Epoch 424/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5081e-04
# Epoch 425/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8965e-04
# Epoch 426/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5137e-04
# Epoch 427/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2306e-04
# Epoch 428/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5105e-04
# Epoch 429/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1359e-04
# Epoch 430/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5973e-04
# Epoch 431/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7888e-04
# Epoch 432/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2898e-04
# Epoch 433/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4847e-04
# Epoch 434/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3413e-04
# Epoch 435/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2039e-04
# Epoch 436/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9062e-04
# Epoch 437/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2723e-04
# Epoch 438/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6348e-04
# Epoch 439/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0461e-04
# Epoch 440/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8875e-04
# Epoch 441/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8003e-04
# Epoch 442/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7578e-04
# Epoch 443/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8821e-04
# Epoch 444/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9753e-04
# Epoch 445/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7158e-04
# Epoch 446/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6569e-04
# Epoch 447/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5894e-04
# Epoch 448/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4401e-04
# Epoch 449/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7727e-04
# Epoch 450/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5871e-04
# Epoch 451/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2880e-04
# Epoch 452/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4950e-04
# Epoch 453/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8281e-04
# Epoch 454/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8369e-04
# Epoch 455/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5879e-04
# Epoch 456/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4280e-04
# Epoch 457/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1528e-04
# Epoch 458/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3815e-04
# Epoch 459/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9223e-04
# Epoch 460/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6554e-04
# Epoch 461/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2772e-04
# Epoch 462/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9181e-04
# Epoch 463/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1918e-04
# Epoch 464/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3207e-04
# Epoch 465/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0431e-04
# Epoch 466/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3964e-04
# Epoch 467/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9274e-04
# Epoch 468/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9481e-04
# Epoch 469/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4403e-04
# Epoch 470/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1673e-04
# Epoch 471/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0415e-04
# Epoch 472/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1152e-04
# Epoch 473/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5899e-04
# Epoch 474/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4653e-04
# Epoch 475/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2498e-04
# Epoch 476/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0327e-04
# Epoch 477/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9800e-05
# Epoch 478/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0579e-04
# Epoch 479/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0902e-04
# Epoch 480/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7558e-05
# Epoch 481/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1560e-04
# Epoch 482/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1620e-04
# Epoch 483/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3028e-04
# Epoch 484/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3184e-04
# Epoch 485/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2123e-04
# Epoch 486/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2690e-04
# Epoch 487/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5328e-04
# Epoch 488/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7843e-04
# Epoch 489/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2924e-04
# Epoch 490/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6663e-04
# Epoch 491/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8574e-04
# Epoch 492/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2260e-04
# Epoch 493/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2777e-04
# Epoch 494/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3323e-04
# Epoch 495/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1624e-04
# Epoch 496/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8623e-04
# Epoch 497/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1888e-04
# Epoch 498/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2350e-05
# Epoch 499/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0751e-04
# Epoch 500/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4686e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Mean Absolute Error (MAE): 0.19367712580864338
# Mean Squared Error (MSE): 0.05490502948946232
# Root Mean Squared Error (RMSE): 0.23431822270037453
# R-squared (R²): -0.2547199138232332
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[317], line 18
#      16 plt.figure(figsize=(10, 6))
#      17 plt.plot(history.history['loss'], label='Training Loss')
# ---> 18 plt.plot(history.history['val_loss'], label='Validation Loss')
#      19 plt.xlabel('Epochs')
#      20 plt.ylabel('Mean Squared Error (MSE)')
#
# KeyError: 'val_loss'

# %%
y_predicted = model.predict(X_test)
plt.plot(y_predicted)
plt.plot(y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
y_predicted = model.predict(X_train)
plt.plot(y_predicted)
plt.plot(y_train)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
